# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Import citypy and random modules to make city list

from citipy import citipy
import random

#import modules to make and export API call
from api_keys import weather_api_key
import requests
import json



#Import modules to create graphs of data
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# %% [markdown]
# ## Generate Cities List

# %%
#Generate 500 random longitudes
randomlong = []
for i in range(0,600):
    n = random.randint(-180,80)
    randomlong.append(n)

#Generate 500 random Latitudes
randomlat = []
for i in range(0,600):
    n = random.randint(-60,80)
    randomlat.append(n)

#Loop through lat/Long to identify cities with citypy
cities = []
for lat, long in zip(randomlat, randomlong):
    city = citipy.nearest_city(lat, long)
    if city not in cities:
        cities.append(city.city_name)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Loop over Cities using series of API calls. 
#Testing one city
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# append firt city from list to url
city_url = url + "&q=" + cities[0]

# Make API call in Json Format
response_single = requests.get(city_url).json()

print(json.dumps(response_single, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.1239,
#         "lon": -100.7654
#     },
#     "dt": 1610603073,
#     "id": 5697939,
#     "main": {
#         "feels_like": 16,
#         "humidity": 61,
#         "pressure": 1006,
#         "temp": 41.95,
#         "temp_max": 46.4,
#         "temp_min": 41
#     },
#     "name": "North Platte",
#     "sys": {
#         "country": "US",
#         "id": 4674,
#         "sunrise": 1610546799,
#         "sunset": 1610581001,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "gust": 56.39,
#         "speed": 39.12
#     }
# }

# %%
#Smaller subset for simplicity
cities_small = cities[0:10]


city_lat = []
city_long = []

temp = []
humidity = [] 
cloudiness = []
wind_speed = []

for city in cities:
        try:
            response = requests.get(url + "&q="+ city).json()
            city_lat.append(round(response["coord"]["lat"],2))
            city_long.append(round(response["coord"]["lon"],2))
            temp.append(response["main"]["temp_max"])
            humidity.append(response["main"]["humidity"])
            cloudiness.append(response["clouds"]["all"])
            wind_speed.append(response["wind"]["speed"])
            
            print(f"The weather stats for the city of {city}, of lat {round(response['coord']['lat'],2)} and long {round(response['coord']['lon'],2)} are: max temp({response['main']['temp_max']}),humidity({response['main']['humidity']}),cloudiness({response['clouds']['all']}) and windspeed({response['wind']['speed']})")
            print("------------------------------------------------------")
            print(len(city_lat))

        except:
            "Exception"

weather_dict = {
    "City": cities[0:len(city_lat)],
    "Latitude":city_lat,
    "Longitude":city_long,

    "Temperature": temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed}

weather_data = pd.DataFrame(weather_dict)
# Out:
# The weather stats for the city of north platte, of lat 41.12 and long -100.77 are: max temp(46.4),humidity(61),cloudiness(1) and windspeed(39.12)
# ------------------------------------------------------
# 1
# The weather stats for the city of bitam, of lat 2.08 and long 11.5 are: max temp(68.81),humidity(92),cloudiness(97) and windspeed(1.36)
# ------------------------------------------------------
# 2
# The weather stats for the city of vaini, of lat -21.2 and long -175.2 are: max temp(82.4),humidity(89),cloudiness(75) and windspeed(6.91)
# ------------------------------------------------------
# 3
# The weather stats for the city of betanzos, of lat 43.28 and long -8.21 are: max temp(44.6),humidity(81),cloudiness(90) and windspeed(5.75)
# ------------------------------------------------------
# 4
# The weather stats for the city of rio grande, of lat -32.03 and long -52.1 are: max temp(67.37),humidity(69),cloudiness(0) and windspeed(13.6)
# ------------------------------------------------------
# 5
# The weather stats for the city of springdale, of lat 36.19 and long -94.13 are: max temp(45),humidity(53),cloudiness(1) and windspeed(10.36)
# ------------------------------------------------------
# 6
# The weather stats for the city of jamestown, of lat 42.1 and long -79.24 are: max temp(37),humidity(80),cloudiness(40) and windspeed(10.36)
# ------------------------------------------------------
# 7
# The weather stats for the city of sao filipe, of lat 14.9 and long -24.5 are: max temp(71.26),humidity(74),cloudiness(99) and windspeed(15.12)
# ------------------------------------------------------
# 8
# The weather stats for the city of qaanaaq, of lat 77.48 and long -69.36 are: max temp(-2.13),humidity(77),cloudiness(18) and windspeed(4.03)
# ------------------------------------------------------
# 9
# The weather stats for the city of harnai, of lat 30.1 and long 67.94 are: max temp(65.97),humidity(17),cloudiness(76) and windspeed(2.75)
# ------------------------------------------------------
# 10
# The weather stats for the city of atuona, of lat -9.8 and long -139.03 are: max temp(77.67),humidity(77),cloudiness(33) and windspeed(10.85)
# ------------------------------------------------------
# 11
# The weather stats for the city of parintins, of lat -2.63 and long -56.74 are: max temp(73.65),humidity(96),cloudiness(48) and windspeed(1.81)
# ------------------------------------------------------
# 12
# The weather stats for the city of tasiilaq, of lat 65.61 and long -37.64 are: max temp(35.6),humidity(69),cloudiness(75) and windspeed(11.41)
# ------------------------------------------------------
# 13
# The weather stats for the city of puerto ayora, of lat -0.74 and long -90.35 are: max temp(75),humidity(95),cloudiness(86) and windspeed(4)
# ------------------------------------------------------
# 14
# The weather stats for the city of chuy, of lat -33.7 and long -53.46 are: max temp(61),humidity(69),cloudiness(0) and windspeed(7.05)
# ------------------------------------------------------
# 15
# The weather stats for the city of kahului, of lat 20.89 and long -156.47 are: max temp(75.2),humidity(69),cloudiness(20) and windspeed(5.75)
# ------------------------------------------------------
# 16
# The weather stats for the city of lebu, of lat -37.62 and long -73.65 are: max temp(53.42),humidity(88),cloudiness(1) and windspeed(15.64)
# ------------------------------------------------------
# 17
# The weather stats for the city of klaksvik, of lat 62.23 and long -6.59 are: max temp(39.2),humidity(81),cloudiness(20) and windspeed(23.02)
# ------------------------------------------------------
# 18
# The weather stats for the city of kodiak, of lat 57.79 and long -152.41 are: max temp(28.4),humidity(93),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 19
# The weather stats for the city of georgetown, of lat 5.41 and long 100.34 are: max temp(86),humidity(62),cloudiness(20) and windspeed(8.05)
# ------------------------------------------------------
# 20
# The weather stats for the city of kazanka, of lat 47.85 and long 32.82 are: max temp(24.8),humidity(93),cloudiness(90) and windspeed(2.24)
# ------------------------------------------------------
# 21
# The weather stats for the city of san patricio, of lat 28.02 and long -97.52 are: max temp(45),humidity(93),cloudiness(1) and windspeed(5.75)
# ------------------------------------------------------
# 22
# The weather stats for the city of floro, of lat 61.6 and long 5.03 are: max temp(23),humidity(74),cloudiness(0) and windspeed(6.91)
# ------------------------------------------------------
# 23
# The weather stats for the city of virden, of lat 39.5 and long -89.77 are: max temp(37),humidity(81),cloudiness(34) and windspeed(5.01)
# ------------------------------------------------------
# 24
# The weather stats for the city of port alfred, of lat -33.59 and long 26.89 are: max temp(66.99),humidity(97),cloudiness(100) and windspeed(3)
# ------------------------------------------------------
# 25
# The weather stats for the city of cape town, of lat -33.93 and long 18.42 are: max temp(70),humidity(77),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 26
# The weather stats for the city of victoria, of lat 22.29 and long 114.16 are: max temp(66),humidity(35),cloudiness(27) and windspeed(1.41)
# ------------------------------------------------------
# 27
# The weather stats for the city of hilo, of lat 19.73 and long -155.09 are: max temp(73.4),humidity(78),cloudiness(1) and windspeed(0.96)
# ------------------------------------------------------
# 28
# The weather stats for the city of rio gallegos, of lat -51.62 and long -69.22 are: max temp(50),humidity(71),cloudiness(40) and windspeed(2.3)
# ------------------------------------------------------
# 29
# The weather stats for the city of moose factory, of lat 51.26 and long -80.61 are: max temp(24.8),humidity(93),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 30
# The weather stats for the city of turayf, of lat 31.67 and long 38.66 are: max temp(51.8),humidity(58),cloudiness(90) and windspeed(4.61)
# ------------------------------------------------------
# 31
# The weather stats for the city of kodiak, of lat 57.79 and long -152.41 are: max temp(28.4),humidity(93),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 32
# The weather stats for the city of tasiilaq, of lat 65.61 and long -37.64 are: max temp(35.6),humidity(69),cloudiness(75) and windspeed(11.41)
# ------------------------------------------------------
# 33
# The weather stats for the city of cidreira, of lat -30.18 and long -50.21 are: max temp(70.41),humidity(69),cloudiness(30) and windspeed(15.23)
# ------------------------------------------------------
# 34
# The weather stats for the city of lompoc, of lat 34.64 and long -120.46 are: max temp(68),humidity(93),cloudiness(1) and windspeed(4.61)
# ------------------------------------------------------
# 35
# The weather stats for the city of maarianhamina, of lat 60.1 and long 19.93 are: max temp(23),humidity(86),cloudiness(90) and windspeed(11.5)
# ------------------------------------------------------
# 36
# The weather stats for the city of moron, of lat -34.65 and long -58.62 are: max temp(70),humidity(60),cloudiness(0) and windspeed(8.01)
# ------------------------------------------------------
# 37
# The weather stats for the city of sao filipe, of lat 14.9 and long -24.5 are: max temp(71.26),humidity(74),cloudiness(99) and windspeed(15.12)
# ------------------------------------------------------
# 38
# The weather stats for the city of hilo, of lat 19.73 and long -155.09 are: max temp(73.4),humidity(78),cloudiness(1) and windspeed(0.96)
# ------------------------------------------------------
# 39
# The weather stats for the city of verkhovazhye, of lat 60.75 and long 42.05 are: max temp(-19.66),humidity(86),cloudiness(61) and windspeed(6.11)
# ------------------------------------------------------
# 40
# The weather stats for the city of samara, of lat 53 and long 50 are: max temp(8.6),humidity(78),cloudiness(40) and windspeed(17.9)
# ------------------------------------------------------
# 41
# The weather stats for the city of clyde river, of lat 70.47 and long -68.59 are: max temp(-4),humidity(84),cloudiness(90) and windspeed(13.8)
# ------------------------------------------------------
# 42
# The weather stats for the city of port alfred, of lat -33.59 and long 26.89 are: max temp(66.99),humidity(97),cloudiness(100) and windspeed(3)
# ------------------------------------------------------
# 43
# The weather stats for the city of iqaluit, of lat 63.75 and long -68.51 are: max temp(-16.01),humidity(76),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# 44
# The weather stats for the city of faanui, of lat -16.48 and long -151.75 are: max temp(81.84),humidity(75),cloudiness(86) and windspeed(16.26)
# ------------------------------------------------------
# 45
# The weather stats for the city of hilo, of lat 19.73 and long -155.09 are: max temp(73.4),humidity(78),cloudiness(1) and windspeed(0.96)
# ------------------------------------------------------
# 46
# The weather stats for the city of santiago, of lat -33.46 and long -70.65 are: max temp(68),humidity(29),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 47
# The weather stats for the city of pedernales, of lat 18.04 and long -71.74 are: max temp(75.79),humidity(71),cloudiness(7) and windspeed(3.87)
# ------------------------------------------------------
# 48
# The weather stats for the city of port-gentil, of lat -0.72 and long 8.78 are: max temp(75.2),humidity(100),cloudiness(20) and windspeed(4.61)
# ------------------------------------------------------
# 49
# The weather stats for the city of lucapa, of lat -8.42 and long 20.74 are: max temp(68.05),humidity(94),cloudiness(100) and windspeed(1.23)
# ------------------------------------------------------
# 50
# The weather stats for the city of ancud, of lat -41.87 and long -73.82 are: max temp(48),humidity(93),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 51
# The weather stats for the city of kuusamo, of lat 65.97 and long 29.18 are: max temp(-32.8),humidity(75),cloudiness(0) and windspeed(1.14)
# ------------------------------------------------------
# 52
# The weather stats for the city of ponta delgada, of lat 37.73 and long -25.67 are: max temp(61),humidity(94),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# 53
# The weather stats for the city of east london, of lat -33.02 and long 27.91 are: max temp(69.8),humidity(100),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# 54
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 55
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 56
# The weather stats for the city of olavarria, of lat -36.89 and long -60.32 are: max temp(60.01),humidity(57),cloudiness(24) and windspeed(7)
# ------------------------------------------------------
# 57
# The weather stats for the city of cabedelo, of lat -6.98 and long -34.83 are: max temp(75.2),humidity(94),cloudiness(40) and windspeed(3.44)
# ------------------------------------------------------
# 58
# The weather stats for the city of saint-philippe, of lat -21.36 and long 55.77 are: max temp(86),humidity(70),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 59
# The weather stats for the city of thompson, of lat 55.74 and long -97.86 are: max temp(26.6),humidity(100),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 60
# The weather stats for the city of lebu, of lat -37.62 and long -73.65 are: max temp(53.42),humidity(88),cloudiness(1) and windspeed(15.64)
# ------------------------------------------------------
# 61
# The weather stats for the city of praia da vitoria, of lat 38.73 and long -27.07 are: max temp(62.6),humidity(88),cloudiness(75) and windspeed(17.94)
# ------------------------------------------------------
# 62
# The weather stats for the city of bredasdorp, of lat -34.53 and long 20.04 are: max temp(68),humidity(88),cloudiness(99) and windspeed(12.66)
# ------------------------------------------------------
# 63
# The weather stats for the city of atuona, of lat -9.8 and long -139.03 are: max temp(77.67),humidity(77),cloudiness(33) and windspeed(10.85)
# ------------------------------------------------------
# 64
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 65
# The weather stats for the city of georgetown, of lat 5.41 and long 100.34 are: max temp(86),humidity(62),cloudiness(20) and windspeed(8.05)
# ------------------------------------------------------
# 66
# The weather stats for the city of ancud, of lat -41.87 and long -73.82 are: max temp(48),humidity(93),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 67
# The weather stats for the city of iqaluit, of lat 63.75 and long -68.51 are: max temp(-16.01),humidity(76),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# 68
# The weather stats for the city of ixtapa, of lat 20.7 and long -105.2 are: max temp(64.42),humidity(58),cloudiness(100) and windspeed(2.62)
# ------------------------------------------------------
# 69
# The weather stats for the city of ushuaia, of lat -54.8 and long -68.3 are: max temp(51.8),humidity(76),cloudiness(75) and windspeed(4.41)
# ------------------------------------------------------
# 70
# The weather stats for the city of villa carlos paz, of lat -31.42 and long -64.5 are: max temp(75.99),humidity(71),cloudiness(95) and windspeed(1.01)
# ------------------------------------------------------
# 71
# The weather stats for the city of salalah, of lat 17.02 and long 54.09 are: max temp(77),humidity(22),cloudiness(40) and windspeed(12.66)
# ------------------------------------------------------
# 72
# The weather stats for the city of chuy, of lat -33.7 and long -53.46 are: max temp(61),humidity(69),cloudiness(0) and windspeed(7.05)
# ------------------------------------------------------
# 73
# The weather stats for the city of mayo, of lat 38.89 and long -76.51 are: max temp(33.8),humidity(100),cloudiness(1) and windspeed(4.38)
# ------------------------------------------------------
# 74
# The weather stats for the city of margate, of lat 51.38 and long 1.39 are: max temp(42.01),humidity(91),cloudiness(100) and windspeed(4)
# ------------------------------------------------------
# 75
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 76
# The weather stats for the city of sitka, of lat 57.05 and long -135.33 are: max temp(37.4),humidity(87),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# 77
# The weather stats for the city of ushuaia, of lat -54.8 and long -68.3 are: max temp(51.8),humidity(76),cloudiness(75) and windspeed(4.41)
# ------------------------------------------------------
# 78
# The weather stats for the city of puerto ayora, of lat -0.74 and long -90.35 are: max temp(75),humidity(95),cloudiness(86) and windspeed(4)
# ------------------------------------------------------
# 79
# The weather stats for the city of kodiak, of lat 57.79 and long -152.41 are: max temp(28.4),humidity(93),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 80
# The weather stats for the city of jutai, of lat -5.18 and long -68.9 are: max temp(72.09),humidity(97),cloudiness(92) and windspeed(1.41)
# ------------------------------------------------------
# 81
# The weather stats for the city of pedasi, of lat 7.53 and long -80.03 are: max temp(78.39),humidity(81),cloudiness(50) and windspeed(14.05)
# ------------------------------------------------------
# 82
# The weather stats for the city of lebu, of lat -37.62 and long -73.65 are: max temp(53.42),humidity(88),cloudiness(1) and windspeed(15.64)
# ------------------------------------------------------
# 83
# The weather stats for the city of port alfred, of lat -33.59 and long 26.89 are: max temp(66.99),humidity(97),cloudiness(100) and windspeed(3)
# ------------------------------------------------------
# 84
# The weather stats for the city of ancud, of lat -41.87 and long -73.82 are: max temp(48),humidity(93),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 85
# The weather stats for the city of ponta do sol, of lat 32.67 and long -17.1 are: max temp(52),humidity(58),cloudiness(97) and windspeed(3)
# ------------------------------------------------------
# 86
# The weather stats for the city of sao marcos, of lat -28.97 and long -51.07 are: max temp(61),humidity(82),cloudiness(31) and windspeed(1.99)
# ------------------------------------------------------
# 87
# The weather stats for the city of pauini, of lat -7.71 and long -66.98 are: max temp(73.56),humidity(97),cloudiness(91) and windspeed(1.63)
# ------------------------------------------------------
# 88
# The weather stats for the city of pella, of lat 59.78 and long 30.82 are: max temp(8.6),humidity(78),cloudiness(20) and windspeed(4.47)
# ------------------------------------------------------
# 89
# The weather stats for the city of arrecife, of lat 28.96 and long -13.55 are: max temp(57.2),humidity(77),cloudiness(0) and windspeed(10.36)
# ------------------------------------------------------
# 90
# The weather stats for the city of aklavik, of lat 68.22 and long -135.01 are: max temp(-14.8),humidity(76),cloudiness(90) and windspeed(5.3)
# ------------------------------------------------------
# 91
# The weather stats for the city of hirtshals, of lat 57.59 and long 9.96 are: max temp(28.99),humidity(86),cloudiness(90) and windspeed(11.5)
# ------------------------------------------------------
# 92
# The weather stats for the city of clyde river, of lat 70.47 and long -68.59 are: max temp(-4),humidity(84),cloudiness(90) and windspeed(13.8)
# ------------------------------------------------------
# 93
# The weather stats for the city of oneonta, of lat 42.45 and long -75.06 are: max temp(33.01),humidity(81),cloudiness(99) and windspeed(1.01)
# ------------------------------------------------------
# 94
# The weather stats for the city of adrar, of lat 20.5 and long -10.07 are: max temp(56.5),humidity(32),cloudiness(30) and windspeed(13.13)
# ------------------------------------------------------
# 95
# The weather stats for the city of pisco, of lat -13.7 and long -76.22 are: max temp(69.8),humidity(78),cloudiness(0) and windspeed(9.22)
# ------------------------------------------------------
# 96
# The weather stats for the city of ostersund, of lat 63.18 and long 14.64 are: max temp(8.6),humidity(85),cloudiness(90) and windspeed(2.3)
# ------------------------------------------------------
# 97
# The weather stats for the city of george town, of lat 5.41 and long 100.34 are: max temp(86),humidity(62),cloudiness(20) and windspeed(8.05)
# ------------------------------------------------------
# 98
# The weather stats for the city of ancud, of lat -41.87 and long -73.82 are: max temp(48),humidity(93),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 99
# The weather stats for the city of hermanus, of lat -34.42 and long 19.23 are: max temp(71.01),humidity(85),cloudiness(86) and windspeed(5.99)
# ------------------------------------------------------
# 100
# The weather stats for the city of atbasar, of lat 51.8 and long 68.33 are: max temp(-12.62),humidity(86),cloudiness(0) and windspeed(6.44)
# ------------------------------------------------------
# 101
# The weather stats for the city of puerto ayora, of lat -0.74 and long -90.35 are: max temp(75),humidity(95),cloudiness(86) and windspeed(4)
# ------------------------------------------------------
# 102
# The weather stats for the city of ancud, of lat -41.87 and long -73.82 are: max temp(48),humidity(93),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 103
# The weather stats for the city of hilo, of lat 19.73 and long -155.09 are: max temp(73.4),humidity(78),cloudiness(1) and windspeed(0.96)
# ------------------------------------------------------
# 104
# The weather stats for the city of tessalit, of lat 20.2 and long 1.01 are: max temp(61.81),humidity(27),cloudiness(0) and windspeed(9.57)
# ------------------------------------------------------
# 105
# The weather stats for the city of mataura, of lat -46.19 and long 168.86 are: max temp(59),humidity(94),cloudiness(19) and windspeed(10)
# ------------------------------------------------------
# 106
# The weather stats for the city of puerto ayora, of lat -0.74 and long -90.35 are: max temp(75),humidity(95),cloudiness(86) and windspeed(4)
# ------------------------------------------------------
# 107
# The weather stats for the city of san quintin, of lat 30.48 and long -115.95 are: max temp(59.47),humidity(47),cloudiness(0) and windspeed(5.14)
# ------------------------------------------------------
# 108
# The weather stats for the city of lebu, of lat -37.62 and long -73.65 are: max temp(53.42),humidity(88),cloudiness(1) and windspeed(15.64)
# ------------------------------------------------------
# 109
# The weather stats for the city of voyinka, of lat 45.87 and long 33.99 are: max temp(32.79),humidity(96),cloudiness(87) and windspeed(3.74)
# ------------------------------------------------------
# 110
# The weather stats for the city of arlit, of lat 18.74 and long 7.39 are: max temp(60.31),humidity(31),cloudiness(0) and windspeed(1.66)
# ------------------------------------------------------
# 111
# The weather stats for the city of jamestown, of lat 42.1 and long -79.24 are: max temp(37),humidity(80),cloudiness(40) and windspeed(10.36)
# ------------------------------------------------------
# 112
# The weather stats for the city of saint-joseph, of lat -21.37 and long 55.62 are: max temp(86),humidity(70),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 113
# The weather stats for the city of provideniya, of lat 64.38 and long -173.3 are: max temp(-0.13),humidity(90),cloudiness(99) and windspeed(5.97)
# ------------------------------------------------------
# 114
# The weather stats for the city of bud, of lat 39.45 and long -86.18 are: max temp(37.99),humidity(70),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# 115
# The weather stats for the city of bethel, of lat 41.37 and long -73.41 are: max temp(34),humidity(80),cloudiness(40) and windspeed(4.56)
# ------------------------------------------------------
# 116
# The weather stats for the city of tombouctou, of lat 20 and long -3 are: max temp(58.64),humidity(32),cloudiness(0) and windspeed(11.68)
# ------------------------------------------------------
# 117
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 118
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 119
# The weather stats for the city of vredendal, of lat -31.67 and long 18.5 are: max temp(75.13),humidity(57),cloudiness(35) and windspeed(3.15)
# ------------------------------------------------------
# 120
# The weather stats for the city of praia, of lat 14.92 and long -23.51 are: max temp(69.8),humidity(68),cloudiness(40) and windspeed(23.02)
# ------------------------------------------------------
# 121
# The weather stats for the city of poway, of lat 32.96 and long -117.04 are: max temp(60.01),humidity(54),cloudiness(1) and windspeed(1.5)
# ------------------------------------------------------
# 122
# The weather stats for the city of makat, of lat 47.65 and long 53.35 are: max temp(22.95),humidity(94),cloudiness(100) and windspeed(34.18)
# ------------------------------------------------------
# 123
# The weather stats for the city of warrington, of lat 53.39 and long -2.58 are: max temp(41),humidity(100),cloudiness(90) and windspeed(11.5)
# ------------------------------------------------------
# 124
# The weather stats for the city of nanortalik, of lat 60.14 and long -45.24 are: max temp(28.33),humidity(94),cloudiness(100) and windspeed(10.04)
# ------------------------------------------------------
# 125
# The weather stats for the city of alofi, of lat -19.06 and long -169.92 are: max temp(77),humidity(94),cloudiness(79) and windspeed(8.05)
# ------------------------------------------------------
# 126
# The weather stats for the city of villa carlos paz, of lat -31.42 and long -64.5 are: max temp(75.99),humidity(71),cloudiness(95) and windspeed(1.01)
# ------------------------------------------------------
# 127
# The weather stats for the city of vila velha, of lat -20.33 and long -40.29 are: max temp(75.2),humidity(88),cloudiness(75) and windspeed(3.44)
# ------------------------------------------------------
# 128
# The weather stats for the city of acapulco, of lat 16.86 and long -99.89 are: max temp(76.28),humidity(70),cloudiness(19) and windspeed(4.92)
# ------------------------------------------------------
# 129
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 130
# The weather stats for the city of barra do garcas, of lat -15.89 and long -52.26 are: max temp(71.58),humidity(92),cloudiness(100) and windspeed(1.52)
# ------------------------------------------------------
# 131
# The weather stats for the city of rawson, of lat -43.3 and long -65.1 are: max temp(67.14),humidity(59),cloudiness(93) and windspeed(24.61)
# ------------------------------------------------------
# 132
# The weather stats for the city of puerto ayora, of lat -0.74 and long -90.35 are: max temp(75),humidity(95),cloudiness(86) and windspeed(4)
# ------------------------------------------------------
# 133
# The weather stats for the city of frederiksvaerk, of lat 55.97 and long 12.02 are: max temp(35.01),humidity(94),cloudiness(10) and windspeed(8.01)
# ------------------------------------------------------
# 134
# The weather stats for the city of castro, of lat -24.79 and long -50.01 are: max temp(63.95),humidity(94),cloudiness(98) and windspeed(9.35)
# ------------------------------------------------------
# 135
# The weather stats for the city of georgetown, of lat 5.41 and long 100.34 are: max temp(86),humidity(62),cloudiness(20) and windspeed(8.05)
# ------------------------------------------------------
# 136
# The weather stats for the city of los llanos de aridane, of lat 28.66 and long -17.92 are: max temp(60.8),humidity(59),cloudiness(0) and windspeed(10.36)
# ------------------------------------------------------
# 137
# The weather stats for the city of hualmay, of lat -11.1 and long -77.61 are: max temp(69.89),humidity(87),cloudiness(99) and windspeed(7.02)
# ------------------------------------------------------
# 138
# The weather stats for the city of ancud, of lat -41.87 and long -73.82 are: max temp(48),humidity(93),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 139
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 140
# The weather stats for the city of praia, of lat 14.92 and long -23.51 are: max temp(69.8),humidity(68),cloudiness(40) and windspeed(23.02)
# ------------------------------------------------------
# 141
# The weather stats for the city of half moon bay, of lat 37.46 and long -122.43 are: max temp(57),humidity(93),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# 142
# The weather stats for the city of ushuaia, of lat -54.8 and long -68.3 are: max temp(51.8),humidity(76),cloudiness(75) and windspeed(4.41)
# ------------------------------------------------------
# 143
# The weather stats for the city of college, of lat 64.86 and long -147.8 are: max temp(-5.8),humidity(77),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# 144
# The weather stats for the city of haines junction, of lat 60.75 and long -137.51 are: max temp(3.2),humidity(85),cloudiness(78) and windspeed(2.3)
# ------------------------------------------------------
# 145
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 146
# The weather stats for the city of bilma, of lat 18.69 and long 12.92 are: max temp(58.64),humidity(49),cloudiness(67) and windspeed(12.21)
# ------------------------------------------------------
# 147
# The weather stats for the city of birecik, of lat 37.03 and long 37.99 are: max temp(46.4),humidity(100),cloudiness(75) and windspeed(7.05)
# ------------------------------------------------------
# 148
# The weather stats for the city of saint augustine, of lat 29.89 and long -81.31 are: max temp(46.99),humidity(93),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# 149
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 150
# The weather stats for the city of atuona, of lat -9.8 and long -139.03 are: max temp(77.67),humidity(77),cloudiness(33) and windspeed(10.85)
# ------------------------------------------------------
# 151
# The weather stats for the city of barrow, of lat 71.29 and long -156.79 are: max temp(-9.4),humidity(77),cloudiness(1) and windspeed(16.11)
# ------------------------------------------------------
# 152
# The weather stats for the city of kargil, of lat 34.57 and long 76.1 are: max temp(2.19),humidity(51),cloudiness(6) and windspeed(0.49)
# ------------------------------------------------------
# 153
# The weather stats for the city of young, of lat -32.68 and long -57.63 are: max temp(61.48),humidity(64),cloudiness(0) and windspeed(13.04)
# ------------------------------------------------------
# 154
# The weather stats for the city of castro, of lat -24.79 and long -50.01 are: max temp(63.95),humidity(94),cloudiness(98) and windspeed(9.35)
# ------------------------------------------------------
# 155
# The weather stats for the city of cape town, of lat -33.93 and long 18.42 are: max temp(70),humidity(77),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 156
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 157
# The weather stats for the city of puerto ayora, of lat -0.74 and long -90.35 are: max temp(75),humidity(95),cloudiness(86) and windspeed(4)
# ------------------------------------------------------
# 158
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 159
# The weather stats for the city of dikson, of lat 73.51 and long 80.55 are: max temp(-29),humidity(81),cloudiness(0) and windspeed(6.15)
# ------------------------------------------------------
# 160
# The weather stats for the city of puerto rondon, of lat 6.28 and long -71.1 are: max temp(72.81),humidity(85),cloudiness(87) and windspeed(5.61)
# ------------------------------------------------------
# 161
# The weather stats for the city of esna, of lat 25.29 and long 32.55 are: max temp(59),humidity(72),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 162
# The weather stats for the city of rio gallegos, of lat -51.62 and long -69.22 are: max temp(50),humidity(71),cloudiness(40) and windspeed(2.3)
# ------------------------------------------------------
# 163
# The weather stats for the city of qaanaaq, of lat 77.48 and long -69.36 are: max temp(-2.13),humidity(77),cloudiness(18) and windspeed(4.03)
# ------------------------------------------------------
# 164
# The weather stats for the city of trairi, of lat -3.28 and long -39.27 are: max temp(78.55),humidity(78),cloudiness(96) and windspeed(8.5)
# ------------------------------------------------------
# 165
# The weather stats for the city of pontivy, of lat 48 and long -3 are: max temp(50),humidity(100),cloudiness(90) and windspeed(6.91)
# ------------------------------------------------------
# 166
# The weather stats for the city of bethel, of lat 41.37 and long -73.41 are: max temp(34),humidity(80),cloudiness(40) and windspeed(4.56)
# ------------------------------------------------------
# 167
# The weather stats for the city of mataura, of lat -46.19 and long 168.86 are: max temp(59),humidity(94),cloudiness(19) and windspeed(10)
# ------------------------------------------------------
# 168
# The weather stats for the city of salalah, of lat 17.02 and long 54.09 are: max temp(77),humidity(22),cloudiness(40) and windspeed(12.66)
# ------------------------------------------------------
# 169
# The weather stats for the city of saint-philippe, of lat -21.36 and long 55.77 are: max temp(86),humidity(70),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 170
# The weather stats for the city of lebu, of lat -37.62 and long -73.65 are: max temp(53.42),humidity(88),cloudiness(1) and windspeed(15.64)
# ------------------------------------------------------
# 171
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 172
# The weather stats for the city of homer, of lat 59.64 and long -151.55 are: max temp(37.4),humidity(81),cloudiness(75) and windspeed(12.66)
# ------------------------------------------------------
# 173
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 174
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 175
# The weather stats for the city of san agustin acasaguastlan, of lat 14.95 and long -89.97 are: max temp(54),humidity(90),cloudiness(91) and windspeed(3)
# ------------------------------------------------------
# 176
# The weather stats for the city of castro, of lat -24.79 and long -50.01 are: max temp(63.95),humidity(94),cloudiness(98) and windspeed(9.35)
# ------------------------------------------------------
# 177
# The weather stats for the city of ilulissat, of lat 69.22 and long -51.1 are: max temp(24.8),humidity(80),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# 178
# The weather stats for the city of ponta do sol, of lat 32.67 and long -17.1 are: max temp(52),humidity(58),cloudiness(97) and windspeed(3)
# ------------------------------------------------------
# 179
# The weather stats for the city of atuona, of lat -9.8 and long -139.03 are: max temp(77.67),humidity(77),cloudiness(33) and windspeed(10.85)
# ------------------------------------------------------
# 180
# The weather stats for the city of ponta do sol, of lat 32.67 and long -17.1 are: max temp(52),humidity(58),cloudiness(97) and windspeed(3)
# ------------------------------------------------------
# 181
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 182
# The weather stats for the city of los llanos de aridane, of lat 28.66 and long -17.92 are: max temp(60.8),humidity(59),cloudiness(0) and windspeed(10.36)
# ------------------------------------------------------
# 183
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 184
# The weather stats for the city of jawa, of lat 31.85 and long 35.94 are: max temp(50),humidity(87),cloudiness(40) and windspeed(11.5)
# ------------------------------------------------------
# 185
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 186
# The weather stats for the city of vila velha, of lat -20.33 and long -40.29 are: max temp(75.2),humidity(88),cloudiness(75) and windspeed(3.44)
# ------------------------------------------------------
# 187
# The weather stats for the city of mataura, of lat -46.19 and long 168.86 are: max temp(59),humidity(94),cloudiness(19) and windspeed(10)
# ------------------------------------------------------
# 188
# The weather stats for the city of ponta do sol, of lat 32.67 and long -17.1 are: max temp(52),humidity(58),cloudiness(97) and windspeed(3)
# ------------------------------------------------------
# 189
# The weather stats for the city of maniitsoq, of lat 65.42 and long -52.9 are: max temp(19.78),humidity(94),cloudiness(100) and windspeed(9.1)
# ------------------------------------------------------
# 190
# The weather stats for the city of cape town, of lat -33.93 and long 18.42 are: max temp(70),humidity(77),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 191
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 192
# The weather stats for the city of barra do garcas, of lat -15.89 and long -52.26 are: max temp(71.58),humidity(92),cloudiness(100) and windspeed(1.52)
# ------------------------------------------------------
# 193
# The weather stats for the city of arraial do cabo, of lat -22.97 and long -42.03 are: max temp(75.25),humidity(89),cloudiness(33) and windspeed(19.24)
# ------------------------------------------------------
# 194
# The weather stats for the city of bethel, of lat 41.37 and long -73.41 are: max temp(34),humidity(80),cloudiness(40) and windspeed(4.56)
# ------------------------------------------------------
# 195
# The weather stats for the city of saldanha, of lat -33.01 and long 17.94 are: max temp(62.6),humidity(88),cloudiness(0) and windspeed(6.91)
# ------------------------------------------------------
# 196
# The weather stats for the city of yellowknife, of lat 62.46 and long -114.35 are: max temp(9),humidity(92),cloudiness(90) and windspeed(11.5)
# ------------------------------------------------------
# 197
# The weather stats for the city of santa cruz, of lat -17.8 and long -63.17 are: max temp(73.4),humidity(94),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# 198
# The weather stats for the city of sergeyevka, of lat 53.88 and long 67.42 are: max temp(-14.8),humidity(82),cloudiness(0) and windspeed(3.11)
# ------------------------------------------------------
# 199
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 200
# The weather stats for the city of axim, of lat 4.87 and long -2.24 are: max temp(78.19),humidity(87),cloudiness(100) and windspeed(5.79)
# ------------------------------------------------------
# 201
# The weather stats for the city of ushuaia, of lat -54.8 and long -68.3 are: max temp(51.8),humidity(76),cloudiness(75) and windspeed(4.41)
# ------------------------------------------------------
# 202
# The weather stats for the city of alofi, of lat -19.06 and long -169.92 are: max temp(77),humidity(94),cloudiness(79) and windspeed(8.05)
# ------------------------------------------------------
# 203
# The weather stats for the city of thompson, of lat 55.74 and long -97.86 are: max temp(26.6),humidity(100),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 204
# The weather stats for the city of tlalnepantla, of lat 19.53 and long -99.22 are: max temp(59),humidity(47),cloudiness(75) and windspeed(5.75)
# ------------------------------------------------------
# 205
# The weather stats for the city of tooele, of lat 40.53 and long -112.3 are: max temp(36),humidity(86),cloudiness(90) and windspeed(5.75)
# ------------------------------------------------------
# 206
# The weather stats for the city of wrexham, of lat 53 and long -3 are: max temp(46.99),humidity(97),cloudiness(100) and windspeed(1.01)
# ------------------------------------------------------
# 207
# The weather stats for the city of bachaquero, of lat 9.97 and long -71.15 are: max temp(77.58),humidity(76),cloudiness(92) and windspeed(7.14)
# ------------------------------------------------------
# 208
# The weather stats for the city of ushuaia, of lat -54.8 and long -68.3 are: max temp(51.8),humidity(76),cloudiness(75) and windspeed(4.41)
# ------------------------------------------------------
# 209
# The weather stats for the city of georgetown, of lat 5.41 and long 100.34 are: max temp(86),humidity(62),cloudiness(20) and windspeed(8.05)
# ------------------------------------------------------
# 210
# The weather stats for the city of treinta y tres, of lat -33.23 and long -54.38 are: max temp(55.22),humidity(79),cloudiness(0) and windspeed(5.7)
# ------------------------------------------------------
# 211
# The weather stats for the city of jamestown, of lat 42.1 and long -79.24 are: max temp(37),humidity(80),cloudiness(40) and windspeed(10.36)
# ------------------------------------------------------
# 212
# The weather stats for the city of petrov val, of lat 50.14 and long 45.21 are: max temp(26.82),humidity(98),cloudiness(100) and windspeed(19.51)
# ------------------------------------------------------
# 213
# The weather stats for the city of luderitz, of lat -26.65 and long 15.16 are: max temp(66.61),humidity(80),cloudiness(96) and windspeed(3.89)
# ------------------------------------------------------
# 214
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 215
# The weather stats for the city of high level, of lat 58.52 and long -117.14 are: max temp(32),humidity(69),cloudiness(75) and windspeed(13.8)
# ------------------------------------------------------
# 216
# The weather stats for the city of banyo, of lat 6.75 and long 11.82 are: max temp(60.48),humidity(33),cloudiness(0) and windspeed(2.95)
# ------------------------------------------------------
# 217
# The weather stats for the city of salalah, of lat 17.02 and long 54.09 are: max temp(77),humidity(22),cloudiness(40) and windspeed(12.66)
# ------------------------------------------------------
# 218
# The weather stats for the city of sinop, of lat 41.77 and long 34.87 are: max temp(44.6),humidity(93),cloudiness(90) and windspeed(4.61)
# ------------------------------------------------------
# 219
# The weather stats for the city of ponta do sol, of lat 32.67 and long -17.1 are: max temp(52),humidity(58),cloudiness(97) and windspeed(3)
# ------------------------------------------------------
# 220
# The weather stats for the city of jamestown, of lat 42.1 and long -79.24 are: max temp(37),humidity(80),cloudiness(40) and windspeed(10.36)
# ------------------------------------------------------
# 221
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 222
# The weather stats for the city of gwadar, of lat 25.12 and long 62.33 are: max temp(69.22),humidity(21),cloudiness(0) and windspeed(2.1)
# ------------------------------------------------------
# 223
# The weather stats for the city of tazmalt, of lat 36.39 and long 4.4 are: max temp(40.3),humidity(74),cloudiness(0) and windspeed(2.46)
# ------------------------------------------------------
# 224
# The weather stats for the city of atuona, of lat -9.8 and long -139.03 are: max temp(77.67),humidity(77),cloudiness(33) and windspeed(10.85)
# ------------------------------------------------------
# 225
# The weather stats for the city of trairi, of lat -3.28 and long -39.27 are: max temp(78.55),humidity(78),cloudiness(96) and windspeed(8.5)
# ------------------------------------------------------
# 226
# The weather stats for the city of hilo, of lat 19.73 and long -155.09 are: max temp(73.4),humidity(78),cloudiness(1) and windspeed(0.96)
# ------------------------------------------------------
# 227
# The weather stats for the city of marawi, of lat 8.0 and long 124.29 are: max temp(81),humidity(88),cloudiness(94) and windspeed(5.99)
# ------------------------------------------------------
# 228
# The weather stats for the city of concordia, of lat -31.39 and long -58.02 are: max temp(68),humidity(71),cloudiness(0) and windspeed(10)
# ------------------------------------------------------
# 229
# The weather stats for the city of torbay, of lat 47.67 and long -52.73 are: max temp(32),humidity(93),cloudiness(90) and windspeed(6.91)
# ------------------------------------------------------
# 230
# The weather stats for the city of cartagena, of lat 10.4 and long -75.51 are: max temp(77),humidity(100),cloudiness(0) and windspeed(6.91)
# ------------------------------------------------------
# 231
# The weather stats for the city of deep river, of lat 46.1 and long -77.5 are: max temp(32),humidity(86),cloudiness(90) and windspeed(2.3)
# ------------------------------------------------------
# 232
# The weather stats for the city of mahebourg, of lat -20.41 and long 57.7 are: max temp(82.4),humidity(74),cloudiness(40) and windspeed(12.66)
# ------------------------------------------------------
# 233
# The weather stats for the city of san quintin, of lat 30.48 and long -115.95 are: max temp(59.47),humidity(47),cloudiness(0) and windspeed(5.14)
# ------------------------------------------------------
# 234
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 235
# The weather stats for the city of nouadhibou, of lat 20.93 and long -17.03 are: max temp(60.8),humidity(48),cloudiness(100) and windspeed(19.57)
# ------------------------------------------------------
# 236
# The weather stats for the city of terra santa, of lat -2.1 and long -56.49 are: max temp(73.29),humidity(96),cloudiness(32) and windspeed(1.16)
# ------------------------------------------------------
# 237
# The weather stats for the city of huarmey, of lat -10.07 and long -78.15 are: max temp(70.43),humidity(86),cloudiness(100) and windspeed(6.38)
# ------------------------------------------------------
# 238
# The weather stats for the city of bage, of lat -31.33 and long -54.11 are: max temp(57.2),humidity(94),cloudiness(0) and windspeed(9.22)
# ------------------------------------------------------
# 239
# The weather stats for the city of mulege, of lat 26.88 and long -111.98 are: max temp(48.96),humidity(64),cloudiness(0) and windspeed(4.27)
# ------------------------------------------------------
# 240
# The weather stats for the city of topsham, of lat 43.93 and long -69.98 are: max temp(37.99),humidity(79),cloudiness(99) and windspeed(7.67)
# ------------------------------------------------------
# 241
# ...
# ------------------------------------------------------
# 474
# The weather stats for the city of atuona, of lat -9.8 and long -139.03 are: max temp(77.67),humidity(77),cloudiness(33) and windspeed(10.85)
# ------------------------------------------------------
# 475
# The weather stats for the city of port elizabeth, of lat -33.92 and long 25.57 are: max temp(68),humidity(100),cloudiness(90) and windspeed(13.8)
# ------------------------------------------------------
# 476
# The weather stats for the city of hilo, of lat 19.73 and long -155.09 are: max temp(73.4),humidity(78),cloudiness(1) and windspeed(0.96)
# ------------------------------------------------------
# 477
# The weather stats for the city of ordubad, of lat 38.91 and long 46.02 are: max temp(42.8),humidity(61),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# 478
# The weather stats for the city of cape town, of lat -33.93 and long 18.42 are: max temp(70),humidity(77),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 479
# The weather stats for the city of provideniya, of lat 64.38 and long -173.3 are: max temp(-0.13),humidity(90),cloudiness(99) and windspeed(5.97)
# ------------------------------------------------------
# 480
# The weather stats for the city of sao joao da barra, of lat -21.64 and long -41.05 are: max temp(75.22),humidity(88),cloudiness(0) and windspeed(15.1)
# ------------------------------------------------------
# 481
# The weather stats for the city of castro, of lat -24.79 and long -50.01 are: max temp(63.95),humidity(94),cloudiness(98) and windspeed(9.35)
# ------------------------------------------------------
# 482
# The weather stats for the city of zachary, of lat 30.65 and long -91.16 are: max temp(44.6),humidity(76),cloudiness(1) and windspeed(10.36)
# ------------------------------------------------------
# 483
# The weather stats for the city of cabo san lucas, of lat 22.89 and long -109.91 are: max temp(60.01),humidity(66),cloudiness(20) and windspeed(3)
# ------------------------------------------------------
# 484
# The weather stats for the city of arraial do cabo, of lat -22.97 and long -42.03 are: max temp(75.25),humidity(89),cloudiness(33) and windspeed(19.24)
# ------------------------------------------------------
# 485
# The weather stats for the city of cape town, of lat -33.93 and long 18.42 are: max temp(70),humidity(77),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 486
# The weather stats for the city of bajil, of lat 15.06 and long 43.29 are: max temp(74.88),humidity(55),cloudiness(0) and windspeed(4.88)
# ------------------------------------------------------
# 487
# The weather stats for the city of cape town, of lat -33.93 and long 18.42 are: max temp(70),humidity(77),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 488
# The weather stats for the city of hofn, of lat 64.25 and long -15.21 are: max temp(42.76),humidity(90),cloudiness(100) and windspeed(6.62)
# ------------------------------------------------------
# 489
# The weather stats for the city of pachino, of lat 36.72 and long 15.09 are: max temp(35.6),humidity(100),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# 490
# The weather stats for the city of san pedro, of lat 14.35 and long 121.02 are: max temp(84.99),humidity(69),cloudiness(40) and windspeed(6.91)
# ------------------------------------------------------
# 491
# The weather stats for the city of san patricio, of lat 28.02 and long -97.52 are: max temp(45),humidity(93),cloudiness(1) and windspeed(5.75)
# ------------------------------------------------------
# 492
# The weather stats for the city of clyde river, of lat 70.47 and long -68.59 are: max temp(-4),humidity(84),cloudiness(90) and windspeed(13.8)
# ------------------------------------------------------
# 493
# The weather stats for the city of prince rupert, of lat 54.32 and long -130.32 are: max temp(41),humidity(75),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# 494
# The weather stats for the city of saint-francois, of lat 46.42 and long 3.91 are: max temp(43),humidity(93),cloudiness(90) and windspeed(10.36)
# ------------------------------------------------------
# 495
# The weather stats for the city of zaranj, of lat 30.97 and long 61.88 are: max temp(35.6),humidity(27),cloudiness(0) and windspeed(6.91)
# ------------------------------------------------------
# 496
# The weather stats for the city of sioux lookout, of lat 50.1 and long -91.92 are: max temp(24.8),humidity(93),cloudiness(90) and windspeed(6.91)
# ------------------------------------------------------
# 497
# The weather stats for the city of beisfjord, of lat 68.38 and long 17.6 are: max temp(23),humidity(86),cloudiness(75) and windspeed(1.14)
# ------------------------------------------------------
# 498
# The weather stats for the city of kahului, of lat 20.89 and long -156.47 are: max temp(75.2),humidity(69),cloudiness(20) and windspeed(5.75)
# ------------------------------------------------------
# 499
# The weather stats for the city of qaqortoq, of lat 60.72 and long -46.03 are: max temp(28.4),humidity(86),cloudiness(90) and windspeed(2.3)
# ------------------------------------------------------
# 500
# The weather stats for the city of odweyne, of lat 9.41 and long 45.06 are: max temp(70.66),humidity(24),cloudiness(25) and windspeed(10.71)
# ------------------------------------------------------
# 501
# The weather stats for the city of sitka, of lat 57.05 and long -135.33 are: max temp(37.4),humidity(87),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# 502
# The weather stats for the city of gouyave, of lat 12.16 and long -61.73 are: max temp(77),humidity(83),cloudiness(20) and windspeed(11.5)
# ------------------------------------------------------
# 503
# The weather stats for the city of arnedo, of lat 42.22 and long -2.1 are: max temp(42.8),humidity(93),cloudiness(0) and windspeed(10.36)
# ------------------------------------------------------
# 504
# The weather stats for the city of fortuna, of lat 40.6 and long -124.16 are: max temp(55.99),humidity(100),cloudiness(90) and windspeed(3.36)
# ------------------------------------------------------
# 505
# The weather stats for the city of caibarien, of lat 22.52 and long -79.47 are: max temp(71.6),humidity(94),cloudiness(40) and windspeed(2.3)
# ------------------------------------------------------
# 506
# The weather stats for the city of eyl, of lat 7.98 and long 49.82 are: max temp(77.25),humidity(62),cloudiness(31) and windspeed(20.67)
# ------------------------------------------------------
# 507
# The weather stats for the city of ampanihy, of lat -24.7 and long 44.75 are: max temp(81.32),humidity(68),cloudiness(69) and windspeed(7.36)
# ------------------------------------------------------
# 508
# The weather stats for the city of tasiilaq, of lat 65.61 and long -37.64 are: max temp(35.6),humidity(69),cloudiness(75) and windspeed(11.41)
# ------------------------------------------------------
# 509
# The weather stats for the city of coquimbo, of lat -29.95 and long -71.34 are: max temp(57.2),humidity(88),cloudiness(20) and windspeed(6.91)
# ------------------------------------------------------
# 510
# The weather stats for the city of ponta do sol, of lat 32.67 and long -17.1 are: max temp(52),humidity(58),cloudiness(97) and windspeed(3)
# ------------------------------------------------------
# 511
# The weather stats for the city of vila franca do campo, of lat 37.72 and long -25.43 are: max temp(61),humidity(94),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# 512
# The weather stats for the city of copiapo, of lat -27.37 and long -70.33 are: max temp(57.2),humidity(82),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 513
# The weather stats for the city of castro, of lat -24.79 and long -50.01 are: max temp(63.95),humidity(94),cloudiness(98) and windspeed(9.35)
# ------------------------------------------------------
# 514
# The weather stats for the city of upington, of lat -28.45 and long 21.26 are: max temp(75.2),humidity(73),cloudiness(40) and windspeed(9.22)
# ------------------------------------------------------
# 515
# The weather stats for the city of hilo, of lat 19.73 and long -155.09 are: max temp(73.4),humidity(78),cloudiness(1) and windspeed(0.96)
# ------------------------------------------------------
# 516
# The weather stats for the city of belmonte, of lat -15.86 and long -38.88 are: max temp(77),humidity(83),cloudiness(75) and windspeed(3.44)
# ------------------------------------------------------
# 517
# The weather stats for the city of victoria, of lat 22.29 and long 114.16 are: max temp(66),humidity(35),cloudiness(27) and windspeed(1.41)
# ------------------------------------------------------
# 518
# The weather stats for the city of lagoa, of lat 39.05 and long -27.98 are: max temp(61.65),humidity(86),cloudiness(19) and windspeed(13.58)
# ------------------------------------------------------
# 519
# The weather stats for the city of cidreira, of lat -30.18 and long -50.21 are: max temp(70.41),humidity(69),cloudiness(30) and windspeed(15.23)
# ------------------------------------------------------
# 520
# The weather stats for the city of nanortalik, of lat 60.14 and long -45.24 are: max temp(28.33),humidity(94),cloudiness(100) and windspeed(10.04)
# ------------------------------------------------------
# 521
# The weather stats for the city of yellowknife, of lat 62.46 and long -114.35 are: max temp(9),humidity(92),cloudiness(90) and windspeed(11.5)
# ------------------------------------------------------
# 522
# The weather stats for the city of tasiilaq, of lat 65.61 and long -37.64 are: max temp(35.6),humidity(69),cloudiness(75) and windspeed(11.41)
# ------------------------------------------------------
# 523
# The weather stats for the city of mitsamiouli, of lat -11.38 and long 43.28 are: max temp(82.26),humidity(73),cloudiness(15) and windspeed(8.61)
# ------------------------------------------------------
# 524
# The weather stats for the city of porciuncula, of lat -20.96 and long -42.04 are: max temp(68.79),humidity(90),cloudiness(18) and windspeed(1.92)
# ------------------------------------------------------
# 525
# The weather stats for the city of mahebourg, of lat -20.41 and long 57.7 are: max temp(82.4),humidity(74),cloudiness(40) and windspeed(12.66)
# ------------------------------------------------------
# 526
# The weather stats for the city of mar del plata, of lat -38.0 and long -57.56 are: max temp(64.99),humidity(59),cloudiness(0) and windspeed(8.05)
# ------------------------------------------------------
# 527
# The weather stats for the city of port hardy, of lat 50.7 and long -127.42 are: max temp(42.8),humidity(93),cloudiness(90) and windspeed(4.61)
# ------------------------------------------------------
# 528
# The weather stats for the city of san patricio, of lat 28.02 and long -97.52 are: max temp(45),humidity(93),cloudiness(1) and windspeed(5.75)
# ------------------------------------------------------
# 529
# The weather stats for the city of cangucu, of lat -31.39 and long -52.68 are: max temp(68),humidity(71),cloudiness(0) and windspeed(1.01)
# ------------------------------------------------------
# 530
# The weather stats for the city of castro, of lat -24.79 and long -50.01 are: max temp(63.95),humidity(94),cloudiness(98) and windspeed(9.35)
# ------------------------------------------------------
# 531
# The weather stats for the city of cordele, of lat 31.96 and long -83.78 are: max temp(37.4),humidity(87),cloudiness(1) and windspeed(7.2)
# ------------------------------------------------------
# 532
# The weather stats for the city of moba, of lat 33.23 and long 105.02 are: max temp(42.78),humidity(51),cloudiness(0) and windspeed(6.17)
# ------------------------------------------------------
# 533
# The weather stats for the city of avenal, of lat 36.0 and long -120.13 are: max temp(53.01),humidity(66),cloudiness(50) and windspeed(3)
# ------------------------------------------------------
# 534
# The weather stats for the city of chimbote, of lat -9.09 and long -78.58 are: max temp(70.21),humidity(86),cloudiness(100) and windspeed(3.58)
# ------------------------------------------------------
# 535
# The weather stats for the city of agadir, of lat 30.42 and long -9.6 are: max temp(42.8),humidity(93),cloudiness(0) and windspeed(4.61)
# ------------------------------------------------------
# 536
# The weather stats for the city of marrakesh, of lat 31.63 and long -8.01 are: max temp(37.4),humidity(93),cloudiness(0) and windspeed(2.3)
# ------------------------------------------------------
# 537
# The weather stats for the city of provideniya, of lat 64.38 and long -173.3 are: max temp(-0.13),humidity(90),cloudiness(99) and windspeed(5.97)
# ------------------------------------------------------
# 538
# The weather stats for the city of imbituba, of lat -28.24 and long -48.67 are: max temp(73.4),humidity(78),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# 539
# The weather stats for the city of port alfred, of lat -33.59 and long 26.89 are: max temp(66.99),humidity(97),cloudiness(100) and windspeed(3)
# ------------------------------------------------------
# 540
# The weather stats for the city of aquiraz, of lat -3.9 and long -38.39 are: max temp(80.6),humidity(78),cloudiness(40) and windspeed(9.22)
# ------------------------------------------------------
# 541
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 542
# The weather stats for the city of cape town, of lat -33.93 and long 18.42 are: max temp(70),humidity(77),cloudiness(0) and windspeed(5.75)
# ------------------------------------------------------
# 543
# The weather stats for the city of thompson, of lat 55.74 and long -97.86 are: max temp(26.6),humidity(100),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# 544
# The weather stats for the city of san patricio, of lat 28.02 and long -97.52 are: max temp(45),humidity(93),cloudiness(1) and windspeed(5.75)
# ------------------------------------------------------
# 545
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 546
# The weather stats for the city of salinopolis, of lat -0.61 and long -47.36 are: max temp(78.78),humidity(85),cloudiness(100) and windspeed(11.07)
# ------------------------------------------------------
# 547
# The weather stats for the city of butembo, of lat 0.15 and long 29.28 are: max temp(63.55),humidity(88),cloudiness(57) and windspeed(0.63)
# ------------------------------------------------------
# 548
# The weather stats for the city of avarua, of lat -21.21 and long -159.78 are: max temp(80.6),humidity(83),cloudiness(90) and windspeed(13.8)
# ------------------------------------------------------
# 549
# The weather stats for the city of gimli, of lat 50.63 and long -96.99 are: max temp(30.2),humidity(80),cloudiness(100) and windspeed(14.97)
# ------------------------------------------------------
# 550
# The weather stats for the city of boda, of lat 4.32 and long 17.47 are: max temp(70.52),humidity(30),cloudiness(39) and windspeed(2.19)
# ------------------------------------------------------
# 551
# The weather stats for the city of rikitea, of lat -23.12 and long -134.97 are: max temp(77.59),humidity(75),cloudiness(90) and windspeed(12.1)
# ------------------------------------------------------
# 552
# The weather stats for the city of kapaa, of lat 22.08 and long -159.32 are: max temp(71.6),humidity(78),cloudiness(90) and windspeed(12.66)
# ------------------------------------------------------
# 553

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(weather_data.head())
#Write df to csv
weather_data.to_csv("City_Data/city_data.csv", index=False, header=True)
# Out:
#            City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0  north platte     41.12    -100.77        46.40        61           1
# 1         bitam      2.08      11.50        68.81        92          97
# 2         vaini    -21.20    -175.20        82.40        89          75
# 3      betanzos     43.28      -8.21        44.60        81          90
# 4        samusu    -32.03     -52.10        67.37        69           0
#
#    Wind Speed
# 0       39.12
# 1        1.36
# 2        6.91
# 3        5.75
# 4       13.60

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Choose Cities with humidity below 100
clean_city_data = weather_data.loc[(weather_data["Humidity"] < 100)]
clean_city_data.head()
# Out:
#            City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0  north platte     41.12    -100.77        46.40        61           1
# 1         bitam      2.08      11.50        68.81        92          97
# 2         vaini    -21.20    -175.20        82.40        89          75
# 3      betanzos     43.28      -8.21        44.60        81          90
# 4        samusu    -32.03     -52.10        67.37        69           0
#
#    Wind Speed
# 0       39.12
# 1        1.36
# 2        6.91
# 3        5.75
# 4       13.60

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
def make_scatter(x, y, title, xlab,ylab):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    x_limit = 80
    x_axis = np.arange(-60, x_limit, 1)
    plt.scatter(x, y, marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
    plt.grid(b=None, which='major', axis='both')
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.title(title)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    print(f"The r-squared value is: {round(rvalue**2,4)}")
    plt.show()
    
    # Print out the r-squared value along with the plot.

make_scatter(clean_city_data["Latitude"],clean_city_data["Temperature"],"Latitude vs Max Temperature(F) (13/01/20)","Latitude","Max Temperature(F)")

print("The r value and regression line indicate a moderate relationship between Latitude and Max Temp with latitudes further from the equator (0) having a reduced maximum temperature ")
# Out:
# The r-squared value is: 0.5093
# The r value and regression line indicate a moderate relationship between Latitude and Max Temp with latitudes further from the equator (0) having a reduced maximum temperature

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
make_scatter(clean_city_data["Latitude"],clean_city_data["Humidity"],"Latitude vs Humidity (13/01/20)","Latitude","Humidity(%)")
print("The r value and regression line indicate a extremely weak relationship between Latitude and Humidity and visually the data does not seem to show a trend.")
# Out:
# The r-squared value is: 0.0016
# The r value and regression line indicate a extremely weak relationship between Latitude and Humidity and visually the data does not seem to show a trend.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
make_scatter(clean_city_data["Latitude"],clean_city_data["Cloudiness"],"Latitude vs Cloudiness(%) (13/01/20)","Latitude","Cloudiness(%)")
print("The r value and regression line indicate a fairly weak relationship between Latitude and Cloudiness with some gradient in the regression but visually very little trend")
# Out:
# The r-squared value is: 0.0061
# The r value and regression line indicate a fairly weak relationship between Latitude and Cloudiness with some gradient in the regression but visually very little trend

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
make_scatter(clean_city_data["Latitude"],clean_city_data["Wind Speed"],"Latitude vs Wind Speed(mph) (13/01/20)","Latitude","Wind Speed (mph)")
print("The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed, and visually the data does not seem to show a trend.")
# Out:
# The r-squared value is: 0.0026
# The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed, and visually the data does not seem to show a trend.

# %% [markdown]
# ## Linear Regression

# %%
North_Hemi_Df = clean_city_data.loc[(clean_city_data["Latitude"] >= 0)]
South_Hemi_Df = clean_city_data.loc[(clean_city_data["Latitude"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Temperature"],"Latitude vs Max Temperature(F) (13/01/20)","Latitude","Max Temperature(F)")
print("The r value and regression line indicate a strong negative relationship between Latitude and Max Temp within the northern hemisphere, with a reduced max temp as distance from equator increases.")
# Out:
# The r-squared value is: 0.7813
# The r value and regression line indicate a strong negative relationship between Latitude and Max Temp within the northern hemisphere, with a reduced max temp as distance from equator increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Temperature"],"Latitude vs Max Temperature(F) (13/01/20)","Latitude","Max Temperature(F)")
print("The r value and regression line indicate a moderate to weak positive relationship between Latitude and Max Temp within the Southern Hemisphere, with a slight trend toward warmer temps closer to the equator.")
# Out:
# The r-squared value is: 0.4768
# The r value and regression line indicate a moderate to weak positive relationship between Latitude and Max Temp within the Southern Hemisphere, with a slight trend toward warmer temps closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Humidity"],"Latitude vs Humidity (13/01/20)","Latitude","Humidity(%)")
print("The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Northern Hemisphere, with a slight trend toward higher humidity levels further from the equator.")
# Out:
# The r-squared value is: 0.1713
# The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Northern Hemisphere, with a slight trend toward higher humidity levels further from the equator.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Humidity"],"Latitude vs Humidity (13/01/20)","Latitude","Humidity(%)")
print("The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Southern Hemisphere, with a slight trend toward higher humidity levels closer to the equator.")
# Out:
# The r-squared value is: 0.0389
# The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Southern Hemisphere, with a slight trend toward higher humidity levels closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Cloudiness"],"Latitude vs Cloudiness(%) (13/01/20)","Latitude","Cloudiness(%)")
print("The r value and regression line indicate a weak relationship between Latitude and Cloudiness within the Northern Hemisphere with some gradient in the regression indicating higher cloud cover further from equator but visually very little trend")
# Out:
# The r-squared value is: 0.0983
# The r value and regression line indicate a weak relationship between Latitude and Cloudiness within the Northern Hemisphere with some gradient in the regression indicating higher cloud cover further from equator but visually very little trend

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Cloudiness"],"Latitude vs Cloudiness(%) (13/01/20)","Latitude","Cloudiness(%)")
print("The r value and regression line indicate a moderate to weak relationship between Latitude and Cloudiness within the Southern hemisphere with some gradient in the regression indicating higher cloud cover closer to the equator.")
# Out:
# The r-squared value is: 0.1066
# The r value and regression line indicate a moderate to weak relationship between Latitude and Cloudiness within the Southern hemisphere with some gradient in the regression indicating higher cloud cover closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Wind Speed"],"Latitude vs Wind Speed(mph) (13/01/20)","Latitude","Wind Speed (mph)")
print("The r value and regression line indicate a relationship between Latitude and Wind Speed within the Norther Hemisphere, with a very slight positive trend indicating greater wind speed further from equator")
# Out:
# The r-squared value is: 0.0066
# The r value and regression line indicate a relationship between Latitude and Wind Speed within the Norther Hemisphere, with a very slight positive trend indicating greater wind speed further from equator

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Wind Speed"],"Latitude vs Wind Speed(mph) (13/01/20)","Latitude","Wind Speed (mph)")
print("The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed within the southern hemisphere, with a very slight negative relationship indicating slightly reduced wind speed closer to equator.")
# Out:
# The r-squared value is: 0.0026
# The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed within the southern hemisphere, with a very slight negative relationship indicating slightly reduced wind speed closer to equator.
