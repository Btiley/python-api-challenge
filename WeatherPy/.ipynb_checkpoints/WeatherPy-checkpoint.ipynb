# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Import citypy and random modules to make city list

from citipy import citipy
import random

#import modules to make and export API call
from api_keys import weather_api_key
import requests
import json



#Import modules to create graphs of data
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# %% [markdown]
# ## Generate Cities List

# %%
#Generate 500 random longitudes
randomlong = []
for i in range(0,600):
    n = random.randint(-180,80)
    randomlong.append(n)

#Generate 500 random Latitudes
randomlat = []
for i in range(0,600):
    n = random.randint(-60,80)
    randomlat.append(n)

#Loop through lat/Long to identify cities with citypy
cities = []
for lat, long in zip(randomlat, randomlong):
    city = citipy.nearest_city(lat, long)
    if city not in cities:
        cities.append(city.city_name)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Loop over Cities using series of API calls. 
#Testing one city
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# append firt city from list to url
city_url = url + "&q=" + cities[0]

# Make API call in Json Format
response_single = requests.get(city_url).json()

print(json.dumps(response_single, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 63
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.7393,
#         "lon": -90.3518
#     },
#     "dt": 1610508430,
#     "id": 3652764,
#     "main": {
#         "feels_like": 79.47,
#         "humidity": 93,
#         "pressure": 1011,
#         "temp": 75,
#         "temp_max": 75,
#         "temp_min": 75
#     },
#     "name": "Puerto Ayora",
#     "sys": {
#         "country": "EC",
#         "id": 2005652,
#         "sunrise": 1610453093,
#         "sunset": 1610496862,
#         "type": 3
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 194,
#         "speed": 8.28
#     }
# }

# %%
#Smaller subset for simplicity
cities_small = cities[0:10]


city_lat = []
temp = []
humidity = [] 
cloudiness = []
wind_speed = []
for city in cities:
        try:
            response = requests.get(url + "&q="+ city).json()
            city_lat.append(round(response["coord"]["lat"],2))
            temp.append(response["main"]["temp_max"])
            humidity.append(response["main"]["humidity"])
            cloudiness.append(response["clouds"]["all"])
            wind_speed.append(response["wind"]["speed"])
            print(f"The weather stats for the city of {city}, of lat {response['coord']['lat']} are: max temp({response['main']['temp_max']}),humidity({response['main']['humidity']}),cloudiness({response['clouds']['all']}) and windspeed({response['wind']['speed']})")
            print("------------------------------------------------------")

        except:
            "Exception"

weather_dict = {
    "City": cities[0:len(city_lat)],
    "Latitude":city_lat,
    "Temperature": temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed}

weather_data = pd.DataFrame(weather_dict)
#weather_data.head()
# Out:
# The weather stats for the city of puerto ayora, of lat -0.7393 are: max temp(75),humidity(93),cloudiness(49) and windspeed(1.99)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of omaruru, of lat -21.4333 are: max temp(66.81),humidity(85),cloudiness(97) and windspeed(2.13)
# ------------------------------------------------------
# The weather stats for the city of atar, of lat 20.5169 are: max temp(55.47),humidity(40),cloudiness(21) and windspeed(11.23)
# ------------------------------------------------------
# The weather stats for the city of mahebourg, of lat -20.4081 are: max temp(78.8),humidity(83),cloudiness(75) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of carutapera, of lat -1.195 are: max temp(76.68),humidity(87),cloudiness(100) and windspeed(4.56)
# ------------------------------------------------------
# The weather stats for the city of faya, of lat 18.3851 are: max temp(42.8),humidity(61),cloudiness(0) and windspeed(3.85)
# ------------------------------------------------------
# The weather stats for the city of hermanus, of lat -34.4187 are: max temp(70),humidity(88),cloudiness(76) and windspeed(5.99)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of provideniya, of lat 64.3833 are: max temp(1.4),humidity(66),cloudiness(90) and windspeed(8.95)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of tsabong, of lat -26.0217 are: max temp(74.77),humidity(66),cloudiness(26) and windspeed(13.96)
# ------------------------------------------------------
# The weather stats for the city of north bend, of lat 43.4065 are: max temp(62.01),humidity(88),cloudiness(90) and windspeed(25.32)
# ------------------------------------------------------
# The weather stats for the city of muros, of lat 42.7762 are: max temp(30.99),humidity(100),cloudiness(4) and windspeed(4.38)
# ------------------------------------------------------
# The weather stats for the city of saint-philippe, of lat -21.3585 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of lebu, of lat -37.6167 are: max temp(52.7),humidity(83),cloudiness(12) and windspeed(16.4)
# ------------------------------------------------------
# The weather stats for the city of tecoanapa, of lat 16.5167 are: max temp(76.03),humidity(77),cloudiness(0) and windspeed(2.01)
# ------------------------------------------------------
# The weather stats for the city of matamba, of lat -8.9833 are: max temp(58.75),humidity(96),cloudiness(100) and windspeed(2.39)
# ------------------------------------------------------
# The weather stats for the city of constitucion, of lat -35.3333 are: max temp(55.33),humidity(56),cloudiness(0) and windspeed(6.42)
# ------------------------------------------------------
# The weather stats for the city of brae, of lat 60.3964 are: max temp(37.4),humidity(81),cloudiness(20) and windspeed(14.97)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of ures, of lat 29.4333 are: max temp(57),humidity(22),cloudiness(0) and windspeed(3)
# ------------------------------------------------------
# The weather stats for the city of vadso, of lat 70.0744 are: max temp(8.6),humidity(66),cloudiness(20) and windspeed(18.41)
# ------------------------------------------------------
# The weather stats for the city of ushuaia, of lat -54.8 are: max temp(44.6),humidity(70),cloudiness(20) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of san borja, of lat -14.8167 are: max temp(74.59),humidity(94),cloudiness(59) and windspeed(2.21)
# ------------------------------------------------------
# The weather stats for the city of pisco, of lat -13.7 are: max temp(69.8),humidity(78),cloudiness(100) and windspeed(2.3)
# ------------------------------------------------------
# The weather stats for the city of carmelo, of lat -33.9892 are: max temp(69.8),humidity(55),cloudiness(0) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of victoria, of lat 22.2855 are: max temp(62.01),humidity(25),cloudiness(0) and windspeed(1.01)
# ------------------------------------------------------
# The weather stats for the city of oranjemund, of lat -28.55 are: max temp(63.34),humidity(92),cloudiness(22) and windspeed(6.69)
# ------------------------------------------------------
# The weather stats for the city of sao filipe, of lat 14.8961 are: max temp(70.23),humidity(74),cloudiness(11) and windspeed(12.53)
# ------------------------------------------------------
# The weather stats for the city of carauari, of lat -4.8828 are: max temp(73.38),humidity(96),cloudiness(39) and windspeed(1.79)
# ------------------------------------------------------
# The weather stats for the city of mikhaylovka, of lat 50.06 are: max temp(24.01),humidity(89),cloudiness(100) and windspeed(13)
# ------------------------------------------------------
# The weather stats for the city of port alfred, of lat -33.5906 are: max temp(68),humidity(96),cloudiness(100) and windspeed(1.01)
# ------------------------------------------------------
# The weather stats for the city of east london, of lat -33.0153 are: max temp(69.8),humidity(100),cloudiness(90) and windspeed(2.3)
# ------------------------------------------------------
# The weather stats for the city of vaini, of lat -21.2 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of boda, of lat 4.3189 are: max temp(63.99),humidity(29),cloudiness(3) and windspeed(3.65)
# ------------------------------------------------------
# The weather stats for the city of lompoc, of lat 34.6391 are: max temp(53.01),humidity(93),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of lebu, of lat -37.6167 are: max temp(52.7),humidity(83),cloudiness(12) and windspeed(16.4)
# ------------------------------------------------------
# The weather stats for the city of sao filipe, of lat 14.8961 are: max temp(70.23),humidity(74),cloudiness(11) and windspeed(12.53)
# ------------------------------------------------------
# The weather stats for the city of rocha, of lat -34.4833 are: max temp(52.95),humidity(70),cloudiness(0) and windspeed(1.28)
# ------------------------------------------------------
# The weather stats for the city of puerto ayora, of lat -0.7393 are: max temp(75),humidity(93),cloudiness(49) and windspeed(1.99)
# ------------------------------------------------------
# The weather stats for the city of punta arenas, of lat -53.15 are: max temp(46.4),humidity(66),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of aviles, of lat 43.5547 are: max temp(44.01),humidity(81),cloudiness(90) and windspeed(10.36)
# ------------------------------------------------------
# The weather stats for the city of bethel, of lat 41.3712 are: max temp(30.99),humidity(80),cloudiness(90) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of vaini, of lat -21.2 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of sao gabriel da cachoeira, of lat -0.1303 are: max temp(72.21),humidity(98),cloudiness(45) and windspeed(1.19)
# ------------------------------------------------------
# The weather stats for the city of lysva, of lat 58.1086 are: max temp(-13.7),humidity(85),cloudiness(76) and windspeed(3.18)
# ------------------------------------------------------
# The weather stats for the city of sao filipe, of lat 14.8961 are: max temp(70.23),humidity(74),cloudiness(11) and windspeed(12.53)
# ------------------------------------------------------
# The weather stats for the city of lebu, of lat -37.6167 are: max temp(52.7),humidity(83),cloudiness(12) and windspeed(16.4)
# ------------------------------------------------------
# The weather stats for the city of jamestown, of lat 42.097 are: max temp(27),humidity(100),cloudiness(90) and windspeed(8.68)
# ------------------------------------------------------
# The weather stats for the city of ponta do sol, of lat 32.6667 are: max temp(57.2),humidity(58),cloudiness(75) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of faya, of lat 18.3851 are: max temp(42.8),humidity(61),cloudiness(0) and windspeed(3.85)
# ------------------------------------------------------
# The weather stats for the city of ribeira grande, of lat 38.5167 are: max temp(60.58),humidity(79),cloudiness(9) and windspeed(5.01)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of ribeira grande, of lat 38.5167 are: max temp(60.58),humidity(79),cloudiness(9) and windspeed(5.01)
# ------------------------------------------------------
# The weather stats for the city of rosetown, of lat 51.5501 are: max temp(30.99),humidity(80),cloudiness(80) and windspeed(16.11)
# ------------------------------------------------------
# The weather stats for the city of la palma, of lat 33.8464 are: max temp(55.4),humidity(76),cloudiness(75) and windspeed(2.33)
# ------------------------------------------------------
# The weather stats for the city of chor, of lat 25.5167 are: max temp(71.73),humidity(18),cloudiness(0) and windspeed(4.83)
# ------------------------------------------------------
# The weather stats for the city of puerto ayora, of lat -0.7393 are: max temp(75),humidity(93),cloudiness(49) and windspeed(1.99)
# ------------------------------------------------------
# The weather stats for the city of sitka, of lat 57.0531 are: max temp(35.6),humidity(87),cloudiness(40) and windspeed(10.36)
# ------------------------------------------------------
# The weather stats for the city of dingle, of lat 10.9995 are: max temp(78.85),humidity(79),cloudiness(100) and windspeed(11.97)
# ------------------------------------------------------
# The weather stats for the city of klaksvik, of lat 62.2266 are: max temp(30.2),humidity(86),cloudiness(20) and windspeed(2.3)
# ------------------------------------------------------
# The weather stats for the city of kaunas, of lat 54.9 are: max temp(30.2),humidity(86),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of mahuva, of lat 21.0914 are: max temp(78.06),humidity(30),cloudiness(1) and windspeed(10.25)
# ------------------------------------------------------
# The weather stats for the city of saint-philippe, of lat -21.3585 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of cap malheureux, of lat -19.9842 are: max temp(81),humidity(82),cloudiness(20) and windspeed(7)
# ------------------------------------------------------
# The weather stats for the city of barrow, of lat 71.2906 are: max temp(-0.4),humidity(78),cloudiness(1) and windspeed(26.46)
# ------------------------------------------------------
# The weather stats for the city of pemba, of lat -12.974 are: max temp(78.8),humidity(89),cloudiness(75) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of hermanus, of lat -34.4187 are: max temp(70),humidity(88),cloudiness(76) and windspeed(5.99)
# ------------------------------------------------------
# The weather stats for the city of porto walter, of lat -8.2686 are: max temp(73.38),humidity(95),cloudiness(98) and windspeed(2.3)
# ------------------------------------------------------
# The weather stats for the city of butembo, of lat 0.15 are: max temp(60.42),humidity(86),cloudiness(43) and windspeed(1.68)
# ------------------------------------------------------
# The weather stats for the city of cape town, of lat -33.9258 are: max temp(72),humidity(78),cloudiness(0) and windspeed(12.66)
# ------------------------------------------------------
# The weather stats for the city of arraial do cabo, of lat -22.9661 are: max temp(75.61),humidity(86),cloudiness(28) and windspeed(23.53)
# ------------------------------------------------------
# The weather stats for the city of inverness, of lat 57.4791 are: max temp(30.99),humidity(86),cloudiness(0) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of saint-philippe, of lat -21.3585 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of kargat, of lat 55.1956 are: max temp(-19.16),humidity(87),cloudiness(8) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of faya, of lat 18.3851 are: max temp(42.8),humidity(61),cloudiness(0) and windspeed(3.85)
# ------------------------------------------------------
# The weather stats for the city of bethel, of lat 41.3712 are: max temp(30.99),humidity(80),cloudiness(90) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of chapais, of lat 49.7834 are: max temp(24.8),humidity(93),cloudiness(90) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of nanortalik, of lat 60.1432 are: max temp(31.1),humidity(95),cloudiness(100) and windspeed(16.35)
# ------------------------------------------------------
# The weather stats for the city of makat, of lat 47.6469 are: max temp(11.08),humidity(94),cloudiness(86) and windspeed(14.94)
# ------------------------------------------------------
# The weather stats for the city of astoria, of lat 46.1879 are: max temp(55.4),humidity(94),cloudiness(90) and windspeed(18.41)
# ------------------------------------------------------
# The weather stats for the city of arraial do cabo, of lat -22.9661 are: max temp(75.61),humidity(86),cloudiness(28) and windspeed(23.53)
# ------------------------------------------------------
# The weather stats for the city of parambu, of lat -6.2111 are: max temp(70.79),humidity(88),cloudiness(100) and windspeed(3.65)
# ------------------------------------------------------
# The weather stats for the city of vila velha, of lat -20.3297 are: max temp(77),humidity(83),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of lichtenfels, of lat 50.1457 are: max temp(30.99),humidity(99),cloudiness(2) and windspeed(7.16)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of niagara falls, of lat 43.1001 are: max temp(33.01),humidity(93),cloudiness(90) and windspeed(10.36)
# ------------------------------------------------------
# The weather stats for the city of iqaluit, of lat 63.7506 are: max temp(-2.2),humidity(71),cloudiness(75) and windspeed(17.27)
# ------------------------------------------------------
# The weather stats for the city of bethel, of lat 41.3712 are: max temp(30.99),humidity(80),cloudiness(90) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of moussoro, of lat 13.6408 are: max temp(64.13),humidity(25),cloudiness(1) and windspeed(10.22)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of kangaatsiaq, of lat 68.3065 are: max temp(21),humidity(98),cloudiness(100) and windspeed(5.48)
# ------------------------------------------------------
# The weather stats for the city of gualeguay, of lat -33.1416 are: max temp(63.1),humidity(44),cloudiness(7) and windspeed(9.91)
# ------------------------------------------------------
# The weather stats for the city of mahebourg, of lat -20.4081 are: max temp(78.8),humidity(83),cloudiness(75) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of tarko-sale, of lat 64.9225 are: max temp(-0.06),humidity(93),cloudiness(98) and windspeed(14.63)
# ------------------------------------------------------
# The weather stats for the city of medyn, of lat 54.9692 are: max temp(21.2),humidity(93),cloudiness(90) and windspeed(6.71)
# ------------------------------------------------------
# The weather stats for the city of cayenne, of lat 4.9333 are: max temp(75.2),humidity(100),cloudiness(75) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of sisimiut, of lat 66.9395 are: max temp(17.58),humidity(95),cloudiness(100) and windspeed(8.25)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of bethel, of lat 41.3712 are: max temp(30.99),humidity(80),cloudiness(90) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of jamestown, of lat 42.097 are: max temp(27),humidity(100),cloudiness(90) and windspeed(8.68)
# ------------------------------------------------------
# The weather stats for the city of ribeira grande, of lat 38.5167 are: max temp(60.58),humidity(79),cloudiness(9) and windspeed(5.01)
# ------------------------------------------------------
# The weather stats for the city of artesia, of lat 33.8658 are: max temp(55.4),humidity(58),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of mahebourg, of lat -20.4081 are: max temp(78.8),humidity(83),cloudiness(75) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of harper, of lat 4.375 are: max temp(78.1),humidity(86),cloudiness(37) and windspeed(9.31)
# ------------------------------------------------------
# The weather stats for the city of gambela, of lat 8.25 are: max temp(78.8),humidity(32),cloudiness(31) and windspeed(1.83)
# ------------------------------------------------------
# The weather stats for the city of naron, of lat 43.5167 are: max temp(39),humidity(100),cloudiness(20) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of sioux lookout, of lat 50.1001 are: max temp(23),humidity(93),cloudiness(1) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of coquimbo, of lat -29.9533 are: max temp(57.2),humidity(88),cloudiness(0) and windspeed(0.67)
# ------------------------------------------------------
# The weather stats for the city of caranavi, of lat -15.8167 are: max temp(65.12),humidity(96),cloudiness(100) and windspeed(1.63)
# ------------------------------------------------------
# The weather stats for the city of serenje, of lat -13.2325 are: max temp(63.9),humidity(97),cloudiness(94) and windspeed(3.11)
# ------------------------------------------------------
# The weather stats for the city of castro, of lat -24.7911 are: max temp(66.07),humidity(97),cloudiness(100) and windspeed(7.29)
# ------------------------------------------------------
# The weather stats for the city of mahebourg, of lat -20.4081 are: max temp(78.8),humidity(83),cloudiness(75) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of cabedelo, of lat -6.9811 are: max temp(75.2),humidity(100),cloudiness(40) and windspeed(9.1)
# ------------------------------------------------------
# The weather stats for the city of jamestown, of lat 42.097 are: max temp(27),humidity(100),cloudiness(90) and windspeed(8.68)
# ------------------------------------------------------
# The weather stats for the city of saint-philippe, of lat -21.3585 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of yellowknife, of lat 62.456 are: max temp(8.6),humidity(85),cloudiness(75) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of ayagoz, of lat 47.9714 are: max temp(9.16),humidity(95),cloudiness(100) and windspeed(21.27)
# ------------------------------------------------------
# The weather stats for the city of ixtapa, of lat 20.7 are: max temp(63.61),humidity(62),cloudiness(82) and windspeed(2.26)
# ------------------------------------------------------
# The weather stats for the city of hilo, of lat 19.7297 are: max temp(75.2),humidity(78),cloudiness(40) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of narsaq, of lat 60.9167 are: max temp(35.6),humidity(69),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of barrow, of lat 71.2906 are: max temp(-0.4),humidity(78),cloudiness(1) and windspeed(26.46)
# ------------------------------------------------------
# The weather stats for the city of pahrump, of lat 36.2083 are: max temp(42.01),humidity(27),cloudiness(86) and windspeed(1.99)
# ------------------------------------------------------
# The weather stats for the city of ponta delgada, of lat 37.7333 are: max temp(59),humidity(94),cloudiness(75) and windspeed(12.66)
# ------------------------------------------------------
# The weather stats for the city of port-gentil, of lat -0.7193 are: max temp(78.75),humidity(84),cloudiness(100) and windspeed(17.9)
# ------------------------------------------------------
# The weather stats for the city of warri, of lat 5.5167 are: max temp(75.72),humidity(90),cloudiness(0) and windspeed(1.83)
# ------------------------------------------------------
# The weather stats for the city of takoradi, of lat 4.8845 are: max temp(78.26),humidity(87),cloudiness(39) and windspeed(6.8)
# ------------------------------------------------------
# The weather stats for the city of lompoc, of lat 34.6391 are: max temp(53.01),humidity(93),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of coquimbo, of lat -29.9533 are: max temp(57.2),humidity(88),cloudiness(0) and windspeed(0.67)
# ------------------------------------------------------
# The weather stats for the city of haines junction, of lat 60.7522 are: max temp(17.6),humidity(86),cloudiness(100) and windspeed(1.14)
# ------------------------------------------------------
# The weather stats for the city of hithadhoo, of lat -0.6 are: max temp(81.95),humidity(80),cloudiness(48) and windspeed(20.15)
# ------------------------------------------------------
# The weather stats for the city of sinnamary, of lat 5.3833 are: max temp(76.33),humidity(87),cloudiness(99) and windspeed(10.47)
# ------------------------------------------------------
# The weather stats for the city of lebu, of lat -37.6167 are: max temp(52.7),humidity(83),cloudiness(12) and windspeed(16.4)
# ------------------------------------------------------
# The weather stats for the city of rawson, of lat -43.3002 are: max temp(58.15),humidity(54),cloudiness(2) and windspeed(8.21)
# ------------------------------------------------------
# The weather stats for the city of santa rita, of lat -7.1139 are: max temp(75.2),humidity(100),cloudiness(40) and windspeed(5.28)
# ------------------------------------------------------
# The weather stats for the city of birjand, of lat 32.8663 are: max temp(21.2),humidity(21),cloudiness(0) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of codrington, of lat -38.2667 are: max temp(67.91),humidity(59),cloudiness(90) and windspeed(15.01)
# ------------------------------------------------------
# The weather stats for the city of suratgarh, of lat 29.3167 are: max temp(65.61),humidity(23),cloudiness(1) and windspeed(3.71)
# ------------------------------------------------------
# The weather stats for the city of ust-kulom, of lat 61.6864 are: max temp(-13.79),humidity(85),cloudiness(34) and windspeed(0.96)
# ------------------------------------------------------
# The weather stats for the city of kilindoni, of lat -7.9139 are: max temp(80.56),humidity(82),cloudiness(68) and windspeed(16.58)
# ------------------------------------------------------
# The weather stats for the city of san quintin, of lat 30.4833 are: max temp(58.73),humidity(43),cloudiness(56) and windspeed(4.34)
# ------------------------------------------------------
# The weather stats for the city of jamestown, of lat 42.097 are: max temp(27),humidity(100),cloudiness(90) and windspeed(8.68)
# ------------------------------------------------------
# The weather stats for the city of sault sainte marie, of lat 46.5168 are: max temp(33.8),humidity(80),cloudiness(90) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of coos bay, of lat 43.3665 are: max temp(63),humidity(88),cloudiness(90) and windspeed(25.32)
# ------------------------------------------------------
# The weather stats for the city of aksu, of lat 41.1231 are: max temp(23.49),humidity(67),cloudiness(0) and windspeed(2.33)
# ------------------------------------------------------
# The weather stats for the city of avarua, of lat -21.2078 are: max temp(78.8),humidity(89),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of ylivieska, of lat 64.0833 are: max temp(12.99),humidity(87),cloudiness(100) and windspeed(21.99)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of delijan, of lat 33.9905 are: max temp(44.29),humidity(42),cloudiness(0) and windspeed(2.59)
# ------------------------------------------------------
# The weather stats for the city of francistown, of lat -21.17 are: max temp(72.3),humidity(77),cloudiness(41) and windspeed(15.41)
# ------------------------------------------------------
# The weather stats for the city of faanui, of lat -16.4833 are: max temp(81.54),humidity(76),cloudiness(100) and windspeed(18.9)
# ------------------------------------------------------
# The weather stats for the city of husavik, of lat 66.0449 are: max temp(17.6),humidity(67),cloudiness(0) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of kargopol, of lat 61.5071 are: max temp(-22.36),humidity(87),cloudiness(1) and windspeed(4.27)
# ------------------------------------------------------
# The weather stats for the city of shelburne, of lat 44.0787 are: max temp(30.2),humidity(86),cloudiness(90) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of ilheus, of lat -14.7889 are: max temp(73.33),humidity(89),cloudiness(3) and windspeed(0.63)
# ------------------------------------------------------
# The weather stats for the city of dombarovskiy, of lat 50.7587 are: max temp(-14.66),humidity(88),cloudiness(0) and windspeed(3.27)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of quiruvilca, of lat -7.9667 are: max temp(39.79),humidity(100),cloudiness(98) and windspeed(1.21)
# ------------------------------------------------------
# The weather stats for the city of puerto ayora, of lat -0.7393 are: max temp(75),humidity(93),cloudiness(49) and windspeed(1.99)
# ------------------------------------------------------
# The weather stats for the city of cape town, of lat -33.9258 are: max temp(72),humidity(78),cloudiness(0) and windspeed(12.66)
# ------------------------------------------------------
# The weather stats for the city of natalio, of lat -26.7167 are: max temp(67.28),humidity(96),cloudiness(92) and windspeed(2.15)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of cabedelo, of lat -6.9811 are: max temp(75.2),humidity(100),cloudiness(40) and windspeed(9.1)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of bathsheba, of lat 13.2167 are: max temp(78.8),humidity(73),cloudiness(20) and windspeed(18.41)
# ------------------------------------------------------
# The weather stats for the city of verkhnyaya toyma, of lat 62.2349 are: max temp(-15.72),humidity(87),cloudiness(1) and windspeed(4.05)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of cabo san lucas, of lat 22.8909 are: max temp(61),humidity(55),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of colares, of lat 38.7992 are: max temp(43),humidity(80),cloudiness(0) and windspeed(2.3)
# ------------------------------------------------------
# The weather stats for the city of cape town, of lat -33.9258 are: max temp(72),humidity(78),cloudiness(0) and windspeed(12.66)
# ------------------------------------------------------
# The weather stats for the city of jamestown, of lat 42.097 are: max temp(27),humidity(100),cloudiness(90) and windspeed(8.68)
# ------------------------------------------------------
# The weather stats for the city of butia, of lat -30.1197 are: max temp(67.73),humidity(74),cloudiness(91) and windspeed(8.32)
# ------------------------------------------------------
# The weather stats for the city of mahebourg, of lat -20.4081 are: max temp(78.8),humidity(83),cloudiness(75) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of san jeronimo, of lat -11.9472 are: max temp(51.35),humidity(75),cloudiness(100) and windspeed(2.39)
# ------------------------------------------------------
# The weather stats for the city of cabo san lucas, of lat 22.8909 are: max temp(61),humidity(55),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of tasiilaq, of lat 65.6145 are: max temp(32),humidity(86),cloudiness(90) and windspeed(41.43)
# ------------------------------------------------------
# The weather stats for the city of arraial do cabo, of lat -22.9661 are: max temp(75.61),humidity(86),cloudiness(28) and windspeed(23.53)
# ------------------------------------------------------
# The weather stats for the city of den helder, of lat 52.9599 are: max temp(42.01),humidity(70),cloudiness(75) and windspeed(19.57)
# ------------------------------------------------------
# The weather stats for the city of punalur, of lat 9 are: max temp(80.6),humidity(89),cloudiness(75) and windspeed(6.6)
# ------------------------------------------------------
# The weather stats for the city of torbay, of lat 47.6666 are: max temp(30.99),humidity(93),cloudiness(90) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of vila franca do campo, of lat 37.7167 are: max temp(59),humidity(94),cloudiness(75) and windspeed(12.66)
# ------------------------------------------------------
# The weather stats for the city of rocha, of lat -34.4833 are: max temp(52.95),humidity(70),cloudiness(0) and windspeed(1.28)
# ------------------------------------------------------
# The weather stats for the city of hacienda heights, of lat 33.9931 are: max temp(57.2),humidity(44),cloudiness(1) and windspeed(1.25)
# ------------------------------------------------------
# The weather stats for the city of iqaluit, of lat 63.7506 are: max temp(-2.2),humidity(71),cloudiness(75) and windspeed(17.27)
# ------------------------------------------------------
# The weather stats for the city of taoudenni, of lat 22.6783 are: max temp(60.73),humidity(29),cloudiness(95) and windspeed(14.85)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of agua verde, of lat 22.9 are: max temp(66),humidity(77),cloudiness(75) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of lagoa, of lat 39.05 are: max temp(59.74),humidity(82),cloudiness(0) and windspeed(7.61)
# ------------------------------------------------------
# The weather stats for the city of cidreira, of lat -30.1811 are: max temp(71.76),humidity(77),cloudiness(98) and windspeed(11.52)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of gamboma, of lat -1.8764 are: max temp(72.55),humidity(88),cloudiness(53) and windspeed(3.8)
# ------------------------------------------------------
# The weather stats for the city of castro, of lat -24.7911 are: max temp(66.07),humidity(97),cloudiness(100) and windspeed(7.29)
# ------------------------------------------------------
# The weather stats for the city of san juan de colon, of lat 8.0313 are: max temp(64.38),humidity(68),cloudiness(50) and windspeed(4)
# ------------------------------------------------------
# The weather stats for the city of vila franca do campo, of lat 37.7167 are: max temp(59),humidity(94),cloudiness(75) and windspeed(12.66)
# ------------------------------------------------------
# The weather stats for the city of fortuna, of lat 40.5982 are: max temp(60.01),humidity(94),cloudiness(90) and windspeed(20.71)
# ------------------------------------------------------
# The weather stats for the city of puerto ayora, of lat -0.7393 are: max temp(75),humidity(93),cloudiness(49) and windspeed(1.99)
# ------------------------------------------------------
# The weather stats for the city of cabo san lucas, of lat 22.8909 are: max temp(61),humidity(55),cloudiness(90) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of nizwa, of lat 22.9333 are: max temp(68.11),humidity(23),cloudiness(0) and windspeed(1.66)
# ------------------------------------------------------
# The weather stats for the city of arraial do cabo, of lat -22.9661 are: max temp(75.61),humidity(86),cloudiness(28) and windspeed(23.53)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of thompson, of lat 55.7435 are: max temp(30.2),humidity(100),cloudiness(40) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of henties bay, of lat -22.116 are: max temp(69.01),humidity(88),cloudiness(100) and windspeed(3.4)
# ------------------------------------------------------
# The weather stats for the city of nyakahanga, of lat -1.6033 are: max temp(60.82),humidity(99),cloudiness(85) and windspeed(0.83)
# ------------------------------------------------------
# The weather stats for the city of punta arenas, of lat -53.15 are: max temp(46.4),humidity(66),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of maragogi, of lat -9.0122 are: max temp(76.17),humidity(85),cloudiness(95) and windspeed(7.05)
# ------------------------------------------------------
# The weather stats for the city of le port, of lat -20.9373 are: max temp(78.8),humidity(89),cloudiness(75) and windspeed(14.97)
# ------------------------------------------------------
# The weather stats for the city of hamilton, of lat 39.1834 are: max temp(30.99),humidity(69),cloudiness(1) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of elizabeth city, of lat 36.2946 are: max temp(34),humidity(100),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of watertown, of lat 42.3709 are: max temp(35.6),humidity(64),cloudiness(90) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of thompson, of lat 55.7435 are: max temp(30.2),humidity(100),cloudiness(40) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of grafton, of lat 42.207 are: max temp(33.01),humidity(69),cloudiness(90) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of tarauaca, of lat -8.1614 are: max temp(73.87),humidity(96),cloudiness(100) and windspeed(2.39)
# ------------------------------------------------------
# The weather stats for the city of porbandar, of lat 21.6422 are: max temp(73.4),humidity(23),cloudiness(0) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of tasiilaq, of lat 65.6145 are: max temp(32),humidity(86),cloudiness(90) and windspeed(41.43)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of medak, of lat 18.0333 are: max temp(78.8),humidity(53),cloudiness(40) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of husavik, of lat 66.0449 are: max temp(17.6),humidity(67),cloudiness(0) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of bathsheba, of lat 13.2167 are: max temp(78.8),humidity(73),cloudiness(20) and windspeed(18.41)
# ------------------------------------------------------
# The weather stats for the city of keti bandar, of lat 24.1447 are: max temp(72.3),humidity(22),cloudiness(0) and windspeed(4.83)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of porbandar, of lat 21.6422 are: max temp(73.4),humidity(23),cloudiness(0) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of fort frances, of lat 48.5999 are: max temp(26.6),humidity(80),cloudiness(1) and windspeed(5.75)
# ------------------------------------------------------
# The weather stats for the city of faanui, of lat -16.4833 are: max temp(81.54),humidity(76),cloudiness(100) and windspeed(18.9)
# ------------------------------------------------------
# The weather stats for the city of chicama, of lat -7.8447 are: max temp(71.22),humidity(77),cloudiness(88) and windspeed(4.45)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of saint george, of lat 37.1041 are: max temp(37.4),humidity(30),cloudiness(1) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of vila velha, of lat -20.3297 are: max temp(77),humidity(83),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of victoria, of lat 22.2855 are: max temp(62.01),humidity(25),cloudiness(0) and windspeed(1.01)
# ------------------------------------------------------
# The weather stats for the city of cidreira, of lat -30.1811 are: max temp(71.76),humidity(77),cloudiness(98) and windspeed(11.52)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of sakakah, of lat 29.9697 are: max temp(41),humidity(70),cloudiness(0) and windspeed(5.86)
# ------------------------------------------------------
# The weather stats for the city of tarija, of lat -21.5355 are: max temp(61.27),humidity(82),cloudiness(100) and windspeed(1.03)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of mopti, of lat 14.6667 are: max temp(66.18),humidity(25),cloudiness(71) and windspeed(10.02)
# ------------------------------------------------------
# The weather stats for the city of port alfred, of lat -33.5906 are: max temp(68),humidity(96),cloudiness(100) and windspeed(1.01)
# ------------------------------------------------------
# The weather stats for the city of punta alta, of lat -38.8759 are: max temp(66.27),humidity(50),cloudiness(0) and windspeed(5.61)
# ------------------------------------------------------
# The weather stats for the city of thompson, of lat 55.7435 are: max temp(30.2),humidity(100),cloudiness(40) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of ushuaia, of lat -54.8 are: max temp(44.6),humidity(70),cloudiness(20) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of san patricio, of lat 28.017 are: max temp(41),humidity(87),cloudiness(40) and windspeed(3.24)
# ------------------------------------------------------
# The weather stats for the city of haines junction, of lat 60.7522 are: max temp(17.6),humidity(86),cloudiness(100) and windspeed(1.14)
# ------------------------------------------------------
# The weather stats for the city of saint george, of lat 37.1041 are: max temp(37.4),humidity(30),cloudiness(1) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of heerenveen, of lat 52.95 are: max temp(37.99),humidity(81),cloudiness(94) and windspeed(15.01)
# ------------------------------------------------------
# The weather stats for the city of victoria, of lat 22.2855 are: max temp(62.01),humidity(25),cloudiness(0) and windspeed(1.01)
# ------------------------------------------------------
# The weather stats for the city of jamestown, of lat 42.097 are: max temp(27),humidity(100),cloudiness(90) and windspeed(8.68)
# ------------------------------------------------------
# The weather stats for the city of ancud, of lat -41.8697 are: max temp(48.99),humidity(87),cloudiness(0) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of raudeberg, of lat 61.9875 are: max temp(33.01),humidity(77),cloudiness(48) and windspeed(25.77)
# ------------------------------------------------------
# The weather stats for the city of sriperumbudur, of lat 12.9689 are: max temp(82.4),humidity(78),cloudiness(40) and windspeed(10.36)
# ------------------------------------------------------
# The weather stats for the city of jamestown, of lat 42.097 are: max temp(27),humidity(100),cloudiness(90) and windspeed(8.68)
# ------------------------------------------------------
# The weather stats for the city of goderich, of lat 43.7501 are: max temp(32),humidity(86),cloudiness(100) and windspeed(13.8)
# ------------------------------------------------------
# The weather stats for the city of quatre cocos, of lat -20.2078 are: max temp(81),humidity(83),cloudiness(75) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# ...
# ------------------------------------------------------
# The weather stats for the city of rodrigues alves, of lat -7.738 are: max temp(73.8),humidity(97),cloudiness(98) and windspeed(2.28)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of killarney, of lat 52.05 are: max temp(49.95),humidity(92),cloudiness(92) and windspeed(6.11)
# ------------------------------------------------------
# The weather stats for the city of pacific grove, of lat 36.6177 are: max temp(53.01),humidity(81),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of uige, of lat -7.6087 are: max temp(63.03),humidity(92),cloudiness(99) and windspeed(2.42)
# ------------------------------------------------------
# The weather stats for the city of hualmay, of lat -11.0964 are: max temp(70.23),humidity(87),cloudiness(100) and windspeed(6.62)
# ------------------------------------------------------
# The weather stats for the city of port hardy, of lat 50.6996 are: max temp(42.8),humidity(100),cloudiness(90) and windspeed(2.3)
# ------------------------------------------------------
# The weather stats for the city of yellowknife, of lat 62.456 are: max temp(8.6),humidity(85),cloudiness(75) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of alta floresta, of lat -9.8756 are: max temp(70.92),humidity(96),cloudiness(100) and windspeed(2.13)
# ------------------------------------------------------
# The weather stats for the city of fort nelson, of lat 58.8053 are: max temp(14),humidity(85),cloudiness(40) and windspeed(2.3)
# ------------------------------------------------------
# The weather stats for the city of punta arenas, of lat -53.15 are: max temp(46.4),humidity(66),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of hithadhoo, of lat -0.6 are: max temp(81.95),humidity(80),cloudiness(48) and windspeed(20.15)
# ------------------------------------------------------
# The weather stats for the city of pangnirtung, of lat 66.1451 are: max temp(-7.38),humidity(84),cloudiness(50) and windspeed(2.37)
# ------------------------------------------------------
# The weather stats for the city of iqaluit, of lat 63.7506 are: max temp(-2.2),humidity(71),cloudiness(75) and windspeed(17.27)
# ------------------------------------------------------
# The weather stats for the city of tasiilaq, of lat 65.6145 are: max temp(32),humidity(86),cloudiness(90) and windspeed(41.43)
# ------------------------------------------------------
# The weather stats for the city of tasiilaq, of lat 65.6145 are: max temp(32),humidity(86),cloudiness(90) and windspeed(41.43)
# ------------------------------------------------------
# The weather stats for the city of avarua, of lat -21.2078 are: max temp(78.8),humidity(89),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of saint george, of lat 37.1041 are: max temp(37.4),humidity(30),cloudiness(1) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of beloha, of lat -25.1667 are: max temp(81.01),humidity(69),cloudiness(36) and windspeed(7.87)
# ------------------------------------------------------
# The weather stats for the city of ribeira grande, of lat 38.5167 are: max temp(60.58),humidity(79),cloudiness(9) and windspeed(5.01)
# ------------------------------------------------------
# The weather stats for the city of norman wells, of lat 65.282 are: max temp(-7.6),humidity(77),cloudiness(90) and windspeed(7)
# ------------------------------------------------------
# The weather stats for the city of arraial do cabo, of lat -22.9661 are: max temp(75.61),humidity(86),cloudiness(28) and windspeed(23.53)
# ------------------------------------------------------
# The weather stats for the city of uyuni, of lat -20.4597 are: max temp(52.12),humidity(61),cloudiness(97) and windspeed(10.63)
# ------------------------------------------------------
# The weather stats for the city of ancud, of lat -41.8697 are: max temp(48.99),humidity(87),cloudiness(0) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of teresina, of lat -5.0892 are: max temp(77),humidity(83),cloudiness(40) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of riyadh, of lat 24.6877 are: max temp(42.8),humidity(52),cloudiness(0) and windspeed(3.98)
# ------------------------------------------------------
# The weather stats for the city of vardo, of lat 70.3705 are: max temp(8.6),humidity(66),cloudiness(20) and windspeed(18.41)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of haines junction, of lat 60.7522 are: max temp(17.6),humidity(86),cloudiness(100) and windspeed(1.14)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of olafsvik, of lat 64.8945 are: max temp(39.97),humidity(75),cloudiness(100) and windspeed(27)
# ------------------------------------------------------
# The weather stats for the city of bethel, of lat 41.3712 are: max temp(30.99),humidity(80),cloudiness(90) and windspeed(2.44)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of vaini, of lat -21.2 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of vaini, of lat -21.2 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of zacatlan, of lat 19.9333 are: max temp(44.64),humidity(91),cloudiness(78) and windspeed(0.96)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of puerto ayora, of lat -0.7393 are: max temp(75),humidity(93),cloudiness(49) and windspeed(1.99)
# ------------------------------------------------------
# The weather stats for the city of kapaa, of lat 22.0752 are: max temp(75.2),humidity(73),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of bambous virieux, of lat -20.3428 are: max temp(81),humidity(83),cloudiness(75) and windspeed(11.5)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of hilo, of lat 19.7297 are: max temp(75.2),humidity(78),cloudiness(40) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of dingle, of lat 10.9995 are: max temp(78.85),humidity(79),cloudiness(100) and windspeed(11.97)
# ------------------------------------------------------
# The weather stats for the city of touros, of lat -5.1989 are: max temp(75.2),humidity(94),cloudiness(75) and windspeed(9.13)
# ------------------------------------------------------
# The weather stats for the city of chishtian mandi, of lat 29.8 are: max temp(65.66),humidity(21),cloudiness(0) and windspeed(3.76)
# ------------------------------------------------------
# The weather stats for the city of mataura, of lat -46.1927 are: max temp(79.12),humidity(40),cloudiness(33) and windspeed(4.72)
# ------------------------------------------------------
# The weather stats for the city of castro, of lat -24.7911 are: max temp(66.07),humidity(97),cloudiness(100) and windspeed(7.29)
# ------------------------------------------------------
# The weather stats for the city of ponta do sol, of lat 32.6667 are: max temp(57.2),humidity(58),cloudiness(75) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of sitka, of lat 57.0531 are: max temp(35.6),humidity(87),cloudiness(40) and windspeed(10.36)
# ------------------------------------------------------
# The weather stats for the city of ponta do sol, of lat 32.6667 are: max temp(57.2),humidity(58),cloudiness(75) and windspeed(8.05)
# ------------------------------------------------------
# The weather stats for the city of barrow, of lat 71.2906 are: max temp(-0.4),humidity(78),cloudiness(1) and windspeed(26.46)
# ------------------------------------------------------
# The weather stats for the city of vaitape, of lat -16.5167 are: max temp(81.54),humidity(76),cloudiness(100) and windspeed(18.84)
# ------------------------------------------------------
# The weather stats for the city of imperial, of lat 33.0334 are: max temp(51.01),humidity(40),cloudiness(1) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of nederland, of lat 29.9744 are: max temp(48.2),humidity(71),cloudiness(90) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of lavrentiya, of lat 65.5833 are: max temp(-6.05),humidity(87),cloudiness(97) and windspeed(6.78)
# ------------------------------------------------------
# The weather stats for the city of sao joao da barra, of lat -21.6403 are: max temp(75.87),humidity(86),cloudiness(83) and windspeed(14.88)
# ------------------------------------------------------
# The weather stats for the city of wajir, of lat 1.7471 are: max temp(74.64),humidity(67),cloudiness(0) and windspeed(12.97)
# ------------------------------------------------------
# The weather stats for the city of boende, of lat -0.2167 are: max temp(71.65),humidity(85),cloudiness(37) and windspeed(1.39)
# ------------------------------------------------------
# The weather stats for the city of arraial do cabo, of lat -22.9661 are: max temp(75.61),humidity(86),cloudiness(28) and windspeed(23.53)
# ------------------------------------------------------
# The weather stats for the city of batavia, of lat 41.85 are: max temp(30.99),humidity(86),cloudiness(1) and windspeed(6.91)
# ------------------------------------------------------
# The weather stats for the city of kodiak, of lat 57.79 are: max temp(32),humidity(93),cloudiness(90) and windspeed(9.04)
# ------------------------------------------------------
# The weather stats for the city of dingle, of lat 10.9995 are: max temp(78.85),humidity(79),cloudiness(100) and windspeed(11.97)
# ------------------------------------------------------
# The weather stats for the city of vaini, of lat -21.2 are: max temp(84.2),humidity(79),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of hilo, of lat 19.7297 are: max temp(75.2),humidity(78),cloudiness(40) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of vila velha, of lat -20.3297 are: max temp(77),humidity(83),cloudiness(75) and windspeed(4.61)
# ------------------------------------------------------
# The weather stats for the city of shache, of lat 38.4167 are: max temp(32.7),humidity(57),cloudiness(0) and windspeed(3.2)
# ------------------------------------------------------
# The weather stats for the city of avarua, of lat -21.2078 are: max temp(78.8),humidity(89),cloudiness(75) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of namibe, of lat -15.1961 are: max temp(71.29),humidity(75),cloudiness(90) and windspeed(4.99)
# ------------------------------------------------------
# The weather stats for the city of nanortalik, of lat 60.1432 are: max temp(31.1),humidity(95),cloudiness(100) and windspeed(16.35)
# ------------------------------------------------------
# The weather stats for the city of atuona, of lat -9.8 are: max temp(77.81),humidity(80),cloudiness(83) and windspeed(17.05)
# ------------------------------------------------------
# The weather stats for the city of upernavik, of lat 72.7868 are: max temp(14.95),humidity(95),cloudiness(100) and windspeed(13.96)
# ------------------------------------------------------
# The weather stats for the city of ambilobe, of lat -13.2 are: max temp(81.52),humidity(82),cloudiness(22) and windspeed(1.57)
# ------------------------------------------------------
# The weather stats for the city of nizwa, of lat 22.9333 are: max temp(68.11),humidity(23),cloudiness(0) and windspeed(1.66)
# ------------------------------------------------------
# The weather stats for the city of faanui, of lat -16.4833 are: max temp(81.54),humidity(76),cloudiness(100) and windspeed(18.9)
# ------------------------------------------------------
# The weather stats for the city of victoria, of lat 22.2855 are: max temp(62.01),humidity(25),cloudiness(0) and windspeed(1.01)
# ------------------------------------------------------
# The weather stats for the city of rikitea, of lat -23.1203 are: max temp(78.33),humidity(76),cloudiness(0) and windspeed(17.36)
# ------------------------------------------------------
# The weather stats for the city of chuy, of lat -33.6971 are: max temp(58.71),humidity(68),cloudiness(0) and windspeed(5.91)
# ------------------------------------------------------
# The weather stats for the city of lewiston, of lat 44.1003 are: max temp(30.99),humidity(69),cloudiness(90) and windspeed(1.61)
# ------------------------------------------------------
# The weather stats for the city of husavik, of lat 66.0449 are: max temp(17.6),humidity(67),cloudiness(0) and windspeed(9.22)
# ------------------------------------------------------
# The weather stats for the city of bonito, of lat -21.1211 are: max temp(76.89),humidity(69),cloudiness(55) and windspeed(2.33)
# ------------------------------------------------------
# The weather stats for the city of abu kamal, of lat 34.4506 are: max temp(56.16),humidity(39),cloudiness(99) and windspeed(7.36)
# ------------------------------------------------------
# The weather stats for the city of tautira, of lat -17.7333 are: max temp(82.4),humidity(65),cloudiness(75) and windspeed(3.44)
# ------------------------------------------------------
# The weather stats for the city of tynset, of lat 62.2759 are: max temp(14),humidity(79),cloudiness(90) and windspeed(1.14)
# ------------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(weather_data)
#Write df to csv
weather_data.to_csv("City_Data/small_city.csv", index=False, header=True)
# Out:
#                 City  Latitude  Temperature  Humidity  Cloudiness  Wind Speed
# 0       puerto ayora     -0.74        75.00        93          49        1.99
# 1            mataura    -46.19        79.12        40          33        4.72
# 2            omaruru    -21.43        66.81        85          97        2.13
# 3               atar     20.52        55.47        40          21       11.23
# 4          mahebourg    -20.41        78.80        83          75       11.50
# ..               ...       ...          ...       ...         ...         ...
# 556  bambous virieux     66.04        17.60        67           0        9.22
# 557          rikitea    -21.12        76.89        69          55        2.33
# 558             hilo     34.45        56.16        39          99        7.36
# 559           dingle    -17.73        82.40        65          75        3.44
# 560           touros     62.28        14.00        79          90        1.14
#
# [561 rows x 6 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Choose Cities with humidity below 100
clean_city_data = weather_data.loc[(weather_data["Humidity"] < 100)]
clean_city_data.head()
# Out:
#            City  Latitude  Temperature  Humidity  Cloudiness  Wind Speed
# 0  puerto ayora     -0.74        75.00        93          49        1.99
# 1       mataura    -46.19        79.12        40          33        4.72
# 2       omaruru    -21.43        66.81        85          97        2.13
# 3          atar     20.52        55.47        40          21       11.23
# 4     mahebourg    -20.41        78.80        83          75       11.50

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
def make_scatter(x, y, title, xlab,ylab):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    x_limit = 80
    x_axis = np.arange(-60, x_limit, 1)
    plt.scatter(x, y, marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
    plt.grid(b=None, which='major', axis='both')
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.title(title)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    print(f"The r-squared value is: {round(rvalue**2,4)}")
    plt.show()
    
    # Print out the r-squared value along with the plot.

make_scatter(clean_city_data["Latitude"],clean_city_data["Temperature"],"Latitude vs Max Temperature(F) (13/01/20)","Latitude","Max Temperature(F)")

print("The r value and regression line indicate a moderate relationship between Latitude and Max Temp with latitudes further from the equator (0) having a reduced maximum temperature ")
# Out:
# The r-squared value is: 0.5523
# The r value and regression line indicate a moderate relationship between Latitude and Max Temp with latitudes further from the equator (0) having a reduced maximum temperature

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
make_scatter(clean_city_data["Latitude"],clean_city_data["Humidity"],"Latitude vs Humidity (13/01/20)","Latitude","Humidity(%)")
print("The r value and regression line indicate a extremely weak relationship between Latitude and Humidity and visually the data does not seem to show a trend."
# Out:
# The r-squared value is: 0.0
# The r value and regression line indicate a extremely relationship between Latitude and Max Temp with latitudes further from the equator (0) having a reduced maximum temperature

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
make_scatter(clean_city_data["Latitude"],clean_city_data["Cloudiness"],"Latitude vs Cloudiness(%) (13/01/20)","Latitude","Cloudiness(%)")
print("The r value and regression line indicate a fairly weak relationship between Latitude and Cloudiness with some gradient in the regression but visually very little trend")
# Out:
# The r-squared value is: 0.0102
# The r value and regression line indicate a fairly weak relationship between Latitude and Cloudiness with some gradient in the regression but visually very little trend

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
make_scatter(clean_city_data["Latitude"],clean_city_data["Wind Speed"],"Latitude vs Wind Speed(mph) (13/01/20)","Latitude","Wind Speed (mph)")
print("The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed, and visually the data does not seem to show a trend.")
# Out:
# The r-squared value is: 0.0066
# The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed, and visually the data does not seem to show a trend.

# %% [markdown]
# ## Linear Regression

# %%
North_Hemi_Df = clean_city_data.loc[(clean_city_data["Latitude"] >= 0)]
South_Hemi_Df = clean_city_data.loc[(clean_city_data["Latitude"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Temperature"],"Latitude vs Max Temperature(F) (13/01/20)","Latitude","Max Temperature(F)")
print("The r value and regression line indicate a strong negative relationship between Latitude and Max Temp within the northern hemisphere, with a reduced max temp as distance from equator increases.")
# Out:
# The r-squared value is: 0.7326
# The r value and regression line indicate a strong negative relationship between Latitude and Max Temp within the northern hemisphere, with a reduced max temp as distance from equator increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Temperature"],"Latitude vs Max Temperature(F) (13/01/20)","Latitude","Max Temperature(F)")
print("The r value and regression line indicate a moderate to weak positive relationship between Latitude and Max Temp within the Southern Hemisphere, with a slight trend toward warmer temps closer to the equator.")
# Out:
# The r-squared value is: 0.2268
# The r value and regression line indicate a moderate to weak positive relationship between Latitude and Max Temp within the Southern Hemisphere, with a slight trend toward warmer temps closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Humidity"],"Latitude vs Humidity (13/01/20)","Latitude","Humidity(%)")
print("The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Northern Hemisphere, with a slight trend toward higher humidity levels further from the equator.")
# Out:
# The r-squared value is: 0.1455
# The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Northern Hemisphere, with a slight trend toward higher humidity levels further from the equator.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Humidity"],"Latitude vs Humidity (13/01/20)","Latitude","Humidity(%)")
print("The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Southern Hemisphere, with a slight trend toward higher humidity levels closer to the equator.")
# Out:
# The r-squared value is: 0.3532
# The r value and regression line indicate a moderate to weak positive relationship between Latitude and Humidity within the Southern Hemisphere, with a slight trend toward higher humidity levels closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Cloudiness"],"Latitude vs Cloudiness(%) (13/01/20)","Latitude","Cloudiness(%)")
print("The r value and regression line indicate a weak relationship between Latitude and Cloudiness within the Northern Hemisphere with some gradient in the regression indicating higher cloud cover further from equator but visually very little trend")
# Out:
# The r-squared value is: 0.11
# The r value and regression line indicate a weak relationship between Latitude and Cloudiness within the Northern Hemisphere with some gradient in the regression indicating higher cloud cover further from equator but visually very little trend

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Cloudiness"],"Latitude vs Cloudiness(%) (13/01/20)","Latitude","Cloudiness(%)")
print("The r value and regression line indicate a moderate to weak relationship between Latitude and Cloudiness within the Southern hemisphere with some gradient in the regression indicating higher cloud cover closer to the equator.")
# Out:
# The r-squared value is: 0.1541
# The r value and regression line indicate a moderate to weak relationship between Latitude and Cloudiness within the Southern hemisphere with some gradient in the regression indicating higher cloud cover closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
make_scatter(North_Hemi_Df["Latitude"],North_Hemi_Df["Wind Speed"],"Latitude vs Wind Speed(mph) (13/01/20)","Latitude","Wind Speed (mph)")
print("The r value and regression line indicate a relationship between Latitude and Wind Speed within the Norther Hemisphere, with a very slight positive trend indicating greater wind speed further from equator")
# Out:
# The r-squared value is: 0.1182
# The r value and regression line indicate a relationship between Latitude and Wind Speed within the Norther Hemisphere, with a very slight positive trend indicating greater wind speed further from equator

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
make_scatter(South_Hemi_Df["Latitude"],South_Hemi_Df["Wind Speed"],"Latitude vs Wind Speed(mph) (13/01/20)","Latitude","Wind Speed (mph)")
print("The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed within the southern hemisphere, with a very slight negative relationship indicating slightly reduced wind speed closer to equator.")
# Out:
# The r-squared value is: 0.0038
# The r value and regression line indicate a extremely weak relationship between Latitude and Wind Speed within the southern hemisphere, with a very slight negative relationship indicating slightly reduced wind speed closer to equator.
